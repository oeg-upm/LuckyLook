# %% [markdown]
# <h1><font color="#113D68" size=5>Deep Learning para Procesamiento del Lenguaje Natural</font></h1>
#
#
#
# <h1><font color="#113D68" size=6>Desarrollar un Embedding + Modelo CNN para análisis de reseñas</font></h1>
#
# <br><br>
# <div style="text-align: right">
# <font color="#113D68" size=3>Manuel Castillo Cara</font><br>
#
# </div>

# %% [markdown]
# ---
#
# <a id="indice"></a>
# <h2><font color="#004D7F" size=5>Índice</font></h2>
#
# * [0. Contexto](#section0)
# * [1. Conjunto de datos de reseñas de películas](#section1)
# * [2. Preparación de datos](#section2)
#     * [2.1. Revisiones de carga y limpieza](#section21)
#     * [2.2. Definir un vocabulario](#section22)
# * [3. Entrenar CNN con capa Embedding](#section3)
# * [4. Evaluar modelo](#section4)
# * [5. Desarrollar un modelo CNN para n-gramas](#section5)
#     * [5.1. Codificar datos](#section51)
#     * [5.2. Definir el modelo](#section52)
#     * [5.3. Mostrar los resultados](#section53)
#     * [5.4. Evaluar el modelo](#section54)
# * [6. Extensiones](#section6)
#     * [6.1. Extensiones sin n-gramas](#section61)
#     * [6.2. Extensiones con n-gramas](#section62)

# %% [markdown]
# ---
# <a id="section0"></a>
# # <font color="#004D7F" size=6> 0. Contexto</font>

# %% [markdown]
# Las incrustaciones de palabras son una técnica para representar texto donde diferentes palabras con significado similar tienen una representación vectorial de valor real similar. Son un avance clave que ha llevado a un gran rendimiento de los modelos de redes neuronales en un conjunto de problemas desafiantes de procesamiento del lenguaje natural. En este tutorial, descubrirá cómo desarrollar modelos de incrustación de palabras con redes neuronales convolucionales para clasificar reseñas de películas. Después de completar este tutorial, sabrás:
# - Cómo preparar datos de texto de reseñas de películas para su clasificación con métodos de aprendizaje profundo.
# - Cómo desarrollar un modelo de clasificación neuronal con incrustación de palabras y capas convolucionales.
# - Cómo evaluar el modelo de clasificación neuronal desarrollado.
#
# Este tutorial se divide en las siguientes partes:
# 1. Conjunto de datos de reseñas de películas
# 2. Preparación de datos
# 3. Entrene CNN con capa de incrustación
# 4. Evaluar modelo

# %% [markdown]
# ---
# <div style="text-align: right"> <font size=5> <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a></font></div>
#
# ---

# %% [markdown]
# <a id="section1"></a>
# # <font color="#004D7F" size=6>1. Conjunto de datos de reseñas de películas</font>

# %% [markdown]
# En este tutorial, utilizaremos el conjunto de datos de revisión de películas.
#
# Después de descomprimir el archivo, tendrá un directorio llamado `txt_sentoken` con dos subdirectorios que contienen el texto `neg` y `pos` para reseñas negativas y positivas. Las revisiones se almacenan una por archivo con una convención de nomenclatura `cv000` a `cv999` para cada `neg` y `pos`.

# %% [markdown]
# ---
# <div style="text-align: right"> <font size=5> <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a></font></div>
#
# ---

# %% [markdown]
# <a id="section2"></a>
# # <font color="#004D7F" size=6>2. Preparación de datos</font>

# %% [markdown]
# Nota: La preparación del conjunto de datos de reseñas de películas se describió por primera vez en capítulos anteriores. En esta sección, veremos 3 cosas:
# 1. Cargar y limpiar los datos para eliminar puntuación y números.
# 2. Definición de un vocabulario de palabras preferidas.

# %% [markdown]
# <a id="section21"></a>
# # <font color="#004D7F" size=5>2.1. Revisiones de carga y limpieza</font>

# %% [markdown]
# Los datos de texto ya están bastante limpios; no se requiere mucha preparación. Sin atascarnos demasiado en los detalles, prepararemos los datos de la siguiente manera:
# - Fichas divididas en espacios en blanco.
# - Eliminar toda la puntuación de las palabras.
# - Eliminar todas las palabras que no estén compuestas únicamente por caracteres alfabéticos.
# - Eliminar todas las palabras que son palabras vacías conocidas.
# - Eliminar todas las palabras que tengan una longitud $\leq$ 1 carácter.
#
# Podemos poner todos estos pasos en una función llamada `clean_doc()` que toma como argumento el texto sin formato cargado desde un archivo y devuelve una lista de tokens limpios. También podemos definir una función `load_doc()` que cargue un documento desde un archivo listo para usar con la función `clean_doc()`. A continuación se muestra un ejemplo de limpieza de la primera crítica positiva.

# %%
from nltk.corpus import stopwords
import string
import re

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# turn a doc into clean tokens
def clean_doc(doc):
	# split into tokens by white space
	tokens = doc.split()
	# prepare regex for char filtering
	re_punc = re.compile('[%s]' % re.escape(string.punctuation))
	# remove punctuation from each word
	tokens = [re_punc.sub('', w) for w in tokens]
	# remove remaining tokens that are not alphabetic
	tokens = [word for word in tokens if word.isalpha()]
	# filter out stop words
	stop_words = set(stopwords.words('english'))
	tokens = [w for w in tokens if not w in stop_words]
	# filter out short tokens
	tokens = [word for word in tokens if len(word) > 1]
	return tokens

# load the document
filename = 'data/txt_sentoken/pos/cv000_29590.txt'
text = load_doc(filename)
tokens = clean_doc(text)
print(tokens)
# Out:
# ['films', 'adapted', 'comic', 'books', 'plenty', 'success', 'whether', 'theyre', 'superheroes', 'batman', 'superman', 'spawn', 'geared', 'toward', 'kids', 'casper', 'arthouse', 'crowd', 'ghost', 'world', 'theres', 'never', 'really', 'comic', 'book', 'like', 'hell', 'starters', 'created', 'alan', 'moore', 'eddie', 'campbell', 'brought', 'medium', 'whole', 'new', 'level', 'mid', 'series', 'called', 'watchmen', 'say', 'moore', 'campbell', 'thoroughly', 'researched', 'subject', 'jack', 'ripper', 'would', 'like', 'saying', 'michael', 'jackson', 'starting', 'look', 'little', 'odd', 'book', 'graphic', 'novel', 'pages', 'long', 'includes', 'nearly', 'consist', 'nothing', 'footnotes', 'words', 'dont', 'dismiss', 'film', 'source', 'get', 'past', 'whole', 'comic', 'book', 'thing', 'might', 'find', 'another', 'stumbling', 'block', 'hells', 'directors', 'albert', 'allen', 'hughes', 'getting', 'hughes', 'brothers', 'direct', 'seems', 'almost', 'ludicrous', 'casting', 'carrot', 'top', 'well', 'anything', 'riddle', 'better', 'direct', 'film', 'thats', 'set', 'ghetto', 'features', 'really', 'violent', 'street', 'crime', 'mad', 'geniuses', 'behind', 'menace', 'ii', 'society', 'ghetto', 'question', 'course', 'whitechapel', 'londons', 'east', 'end', 'filthy', 'sooty', 'place', 'whores', 'called', 'unfortunates', 'starting', 'get', 'little', 'nervous', 'mysterious', 'psychopath', 'carving', 'profession', 'surgical', 'precision', 'first', 'stiff', 'turns', 'copper', 'peter', 'godley', 'robbie', 'coltrane', 'world', 'enough', 'calls', 'inspector', 'frederick', 'abberline', 'johnny', 'depp', 'blow', 'crack', 'case', 'abberline', 'widower', 'prophetic', 'dreams', 'unsuccessfully', 'tries', 'quell', 'copious', 'amounts', 'absinthe', 'opium', 'upon', 'arriving', 'whitechapel', 'befriends', 'unfortunate', 'named', 'mary', 'kelly', 'heather', 'graham', 'say', 'isnt', 'proceeds', 'investigate', 'horribly', 'gruesome', 'crimes', 'even', 'police', 'surgeon', 'cant', 'stomach', 'dont', 'think', 'anyone', 'needs', 'briefed', 'jack', 'ripper', 'wont', 'go', 'particulars', 'say', 'moore', 'campbell', 'unique', 'interesting', 'theory', 'identity', 'killer', 'reasons', 'chooses', 'slay', 'comic', 'dont', 'bother', 'cloaking', 'identity', 'ripper', 'screenwriters', 'terry', 'hayes', 'vertical', 'limit', 'rafael', 'yglesias', 'les', 'mis', 'rables', 'good', 'job', 'keeping', 'hidden', 'viewers', 'end', 'funny', 'watch', 'locals', 'blindly', 'point', 'finger', 'blame', 'jews', 'indians', 'englishman', 'could', 'never', 'capable', 'committing', 'ghastly', 'acts', 'hells', 'ending', 'whistling', 'stonecutters', 'song', 'simpsons', 'days', 'holds', 'back', 'electric', 'carwho', 'made', 'steve', 'guttenberg', 'star', 'dont', 'worry', 'itll', 'make', 'sense', 'see', 'onto', 'hells', 'appearance', 'certainly', 'dark', 'bleak', 'enough', 'surprising', 'see', 'much', 'looks', 'like', 'tim', 'burton', 'film', 'planet', 'apes', 'times', 'seems', 'like', 'sleepy', 'hollow', 'print', 'saw', 'wasnt', 'completely', 'finished', 'color', 'music', 'finalized', 'comments', 'marilyn', 'manson', 'cinematographer', 'peter', 'deming', 'dont', 'say', 'word', 'ably', 'captures', 'dreariness', 'victorianera', 'london', 'helped', 'make', 'flashy', 'killing', 'scenes', 'remind', 'crazy', 'flashbacks', 'twin', 'peaks', 'even', 'though', 'violence', 'film', 'pales', 'comparison', 'blackandwhite', 'comic', 'oscar', 'winner', 'martin', 'childs', 'shakespeare', 'love', 'production', 'design', 'turns', 'original', 'prague', 'surroundings', 'one', 'creepy', 'place', 'even', 'acting', 'hell', 'solid', 'dreamy', 'depp', 'turning', 'typically', 'strong', 'performance', 'deftly', 'handling', 'british', 'accent', 'ians', 'holm', 'joe', 'goulds', 'secret', 'richardson', 'dalmatians', 'log', 'great', 'supporting', 'roles', 'big', 'surprise', 'graham', 'cringed', 'first', 'time', 'opened', 'mouth', 'imagining', 'attempt', 'irish', 'accent', 'actually', 'wasnt', 'half', 'bad', 'film', 'however', 'good', 'stro ...

# %% [markdown]
# Ejecutar el ejemplo imprime una larga lista de tokens limpios. Hay muchos más pasos de limpieza que queramos explorar y los dejo como ejercicios adicionales.

# %% [markdown]
# <a id="section22"></a>
# # <font color="#004D7F" size=5>2.2. Definir un vocabulario</font>

# %% [markdown]
# Podemos desarrollar un vocabulario a modo de `Counter`, que es un diccionario de mapeo de palabras y su conteo que nos permite actualizar y consultar fácilmente. Cada documento se puede agregar a `Counter` (una nueva función llamada `add_doc_to_vocab()`) y podemos pasar por alto todas las revisiones en el directorio negativo y luego en el directorio positivo (una nueva función llamada `process_docs()`).
#
# - Muestra que tenemos un vocabulario de 44,276 palabras.
# - También podemos ver una muestra de las 50 palabras más utilizadas en las reseñas de películas.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <i class="fa fa-info-circle" aria-hidden="true"></i>
# Más información sobre el objeto [`Counter`](https://docs.python.org/3/library/collections.html#collections.Counter)

# %%
from os import listdir
from collections import Counter

# load doc and add to vocab
def add_doc_to_vocab(filename, vocab):
	# load doc
	doc = load_doc(filename)
	# clean doc
	tokens = clean_doc(doc)
	# update counts
	vocab.update(tokens)

# load all docs in a directory
def process_docs(directory, vocab):
	# walk through all files in the folder
	for filename in listdir(directory):
		# skip any reviews in the test set
		if filename.startswith('cv9'):
			continue
		# create the full path of the file to open
		path = directory + '/' + filename
		# add doc to vocab
		add_doc_to_vocab(path, vocab)

# define vocab
vocab = Counter()
# add all docs to vocab
process_docs('data/txt_sentoken/pos', vocab)
process_docs('data/txt_sentoken/neg', vocab)
# print the size of the vocab
print(len(vocab))
# print the top words in the vocab
print(vocab.most_common(50))
# Out:
# 44276
# [('film', 7983), ('one', 4946), ('movie', 4826), ('like', 3201), ('even', 2262), ('good', 2080), ('time', 2041), ('story', 1907), ('films', 1873), ('would', 1844), ('much', 1824), ('also', 1757), ('characters', 1735), ('get', 1724), ('character', 1703), ('two', 1643), ('first', 1588), ('see', 1557), ('way', 1515), ('well', 1511), ('make', 1418), ('really', 1407), ('little', 1351), ('life', 1334), ('plot', 1288), ('people', 1269), ('bad', 1248), ('could', 1248), ('scene', 1241), ('movies', 1238), ('never', 1201), ('best', 1179), ('new', 1140), ('scenes', 1135), ('man', 1131), ('many', 1130), ('doesnt', 1118), ('know', 1092), ('dont', 1086), ('hes', 1024), ('great', 1014), ('another', 992), ('action', 985), ('love', 977), ('us', 967), ('go', 952), ('director', 948), ('end', 946), ('something', 945), ('still', 936)]

# %% [markdown]
# Podemos recorrer el vocabulario y eliminar todas las palabras que tienen poca ocurrencia, como que solo se usan una o dos veces en todas las revisiones.
# - Por ejemplo, el siguiente fragmento recuperará solo los tokens que aparecen 2 o más veces en todas las revisiones.
# - Con esta adición muestra que el tamaño del vocabulario se reduce en un poco más de la mitad de su tamaño, de 44.276 a 25.767 palabras.

# %%
# keep tokens with a min occurrence
min_occurrence = 2
tokens = [k for k,c in vocab.items() if c >= min_occurrence]
print(len(tokens))
# Out:
# 25767

# %% [markdown]
# - Guardamos en un nuevo vocabulario en `vocab.txt` que luego podemos cargar y usar para filtrar reseñas de películas antes de codificarlas para el modelado.
# - Definimos una nueva función llamada `save_list()` que guarda el vocabulario en un archivo, con una palabra por línea. Por ejemplo:

# %%
# save list to file
def save_list(lines, filename):
	# convert lines to a single blob of text
	data = '\n'.join(lines)
	# open file
	file = open(filename, 'w')
	# write text
	file.write(data)
	# close file
	file.close()

# %%
# save tokens to a vocabulary file
save_list(tokens, 'vocab.txt')

# %% [markdown]
# El orden de las palabras en su archivo será diferente, pero debería verse como el siguiendo:

# %%
archivo = open("vocab.txt")
print(archivo.read())
# Out:
# one
# fun
# activity
# parents
# holidays
# suggest
# old
# film
# see
# interest
# kids
# although
# blackandwhite
# films
# frequently
# viewed
# suspect
# ones
# color
# greeted
# open
# mind
# find
# colorful
# action
# even
# six
# decades
# ago
# real
# possibility
# take
# home
# hit
# family
# wandered
# classic
# section
# local
# video
# store
# day
# picked
# copy
# adventures
# robin
# hood
# high
# spirited
# version
# walter
# scott
# story
# nominated
# academy
# award
# best
# picture
# winner
# three
# oscars
# wolfgang
# melodramatic
# music
# ralph
# dawsons
# fast
# paced
# editing
# carl
# jules
# lush
# sets
# probably
# remembered
# errol
# charismatic
# acting
# sir
# flynn
# handsome
# figure
# smile
# charms
# audience
# clearly
# time
# let
# cut
# chase
# say
# tape
# indeed
# popular
# rhodes
# household
# littlest
# jeffrey
# age
# liked
# much
# least
# times
# maybe
# ill
# discuss
# fascination
# usual
# end
# review
# simply
# stated
# derives
# success
# genre
# swashbuckler
# fights
# hundred
# men
# without
# scratch
# considered
# little
# james
# bond
# production
# values
# raise
# level
# rich
# poor
# steals
# gives
# every
# schoolchild
# knows
# movie
# however
# seems
# less
# interested
# income
# redistribution
# fighting
# king
# country
# courage
# athletic
# skills
# serves
# role
# model
# lovely
# olivia
# de
# havilland
# playing
# lady
# marian
# heavy
# romantic
# overtones
# filmed
# typical
# richly
# colors
# produced
# early
# technicolor
# flesh
# tones
# overly
# pink
# subtleties
# match
# perfectly
# wonderfully
# exaggerated
# players
# scene
# wouldnt
# fall
# shows
# incognito
# win
# contest
# outcome
# course
# doesnt
# splitting
# mans
# arrow
# watching
# today
# provide
# jarring
# moments
# sherlock
# holmes
# villain
# guy
# example
# seem
# right
# basil
# reallife
# identity
# outside
# famous
# wigs
# makeup
# department
# bad
# look
# like
# rejects
# mel
# brooks
# comedy
# cinema
# era
# people
# die
# gentle
# prick
# sword
# nasty
# bloody
# holes
# spoil
# wardrobe
# looks
# guys
# banished
# rather
# killed
# lovers
# go
# handinhand
# nothing
# explicitly
# sexual
# kissing
# result
# wonderful
# fairy
# tale
# delightful
# cartoonish
# figures
# hollywood
# rarely
# makes
# quality
# anymore
# try
# savor
# runs
# rated
# containing
# absolutely
# offensive
# would
# get
# rating
# fine
# ages
# thinks
# great
# recommends
# particularly
# likely
# pictures
# hates
# sight
# blood
# movies
# favorite
# parts
# battles
# ending
# characters
# richard
# ian
# hunter
# towards
# middle
# sweet
# hereafter
# crowded
# school
# bus
# skids
# icy
# road
# surface
# rounds
# bend
# careens
# steel
# guard
# rail
# disappears
# long
# shot
# vehicle
# slowly
# sliding
# across
# snowcovered
# field
# pauses
# moment
# cracks
# weight
# bright
# yellow
# vanishes
# effortless
# single
# smooth
# second
# compare
# last
# eighty
# minutes
# titanic
# behemoth
# sinks
# spectacularly
# watery
# demise
# youll
# appreciate
# futility
# comparing
# greatness
# epitomizes
# thats
# independent
# canadian
# director
# atom
# egoyans
# sensational
# dont
# inside
# payload
# screaming
# terrified
# children
# bloodied
# battered
# explode
# break
# thousand
# tiny
# pieces
# leaves
# silently
# slips
# beneath
# frozen
# lake
# horrifying
# sequence
# made
# calm
# distance
# using
# nonlinear
# approach
# narrative
# egoyan
# shifts
# back
# forward
# connecting
# us
# inhabitants
# small
# british
# columbian
# town
# severely
# affected
# tragedy
# fourteen
# died
# accident
# leaving
# paralyzed
# grief
# catalyst
# center
# ambulance
# chaser
# mitchell
# stephens
# moving
# performance
# holm
# comes
# sam
# dent
# persuade
# townsfolk
# engage
# class
# suit
# believe
# accidents
# functions
# concerned
# involved
# observer
# scribbling
# details
# notebook
# providing
# opportunity
# reach
# kind
# closure
# harrowing
# aftermath
# initial
# drive
# may
# financial
# third
# total
# settlement
# wins
# involvement
# provides
# outlet
# come
# grips
# loss
# selfdestructive
# drugaddicted
# daughter
# clinics
# halfway
# houses
# detox
# years
# attention
# detail
# ability
# establish
# mood
# impeccable
# sound
# boiling
# resonates
# plaintive
# cry
# mychael
# danna
# composed
# shimmering
# ice
# storm
# contributes
# another
# memorable
# score
# shivers
# tingles
# equally
# impressive
# paul
# sarossys
# cinematography
# capturing
# imposing
# splendidly
# shadowy
# wall
# calendar
# illuminate
# portions
# room
# undeniably
# grim
# urges
# viewer
# grab
# onto
# life
# hands
# generous
# subtlety
# emotion
# contact
# jodie
# foster
# actresses
# stuart
# starring
# matthew
# mcconaughey
# john
# hurt
# robert
# zemeckis
# star
# predictable
# mit
# phillip
# morrison
# start
# surprising
# familiar
# prof
# morrisons
# work
# picks
# steam
# gradually
# building
# irresistable
# juggernaut
# good
# often
# case
# terms
# pandering
# technological
# geek
# side
# left
# science
# fiction
# supposed
# evoke
# sense
# wonder
# universe
# questions
# whats
# technology
# overshadow
# characterization
# unusual
# amongst
# hightech
# except
# arroway
# hadden
# actors
# exceptional
# caliber
# supporting
# cast
# especially
# certainly
# better
# roles
# stephen
# ward
# scandal
# justice
# lights
# generation
# fosters
# never
# strong
# finally
# meets
# scenes
# build
# pacing
# subtle
# panoramas
# radio
# dishes
# new
# mexico
# puerto
# rico
# beautiful
# politics
# character
# attempting
# obtain
# funding
# research
# places
# trite
# entertaining
# short
# confronted
# rob
# lowe
# presidential
# meeting
# alien
# invitation
# sparks
# consider
# vehicles
# could
# explored
# tremendous
# dynamics
# two
# everything
# else
# onesided
# stand
# showed
# cabinet
# table
# core
# set
# surrealistic
# beach
# world
# vega
# feels
# lot
# writer
# book
# female
# protagonists
# encounters
# immensely
# superior
# intelligence
# computer
# manufactured
# mankind
# illusion
# drawn
# memory
# evokes
# gene
# roddenberrys
# trek
# pilot
# cage
# later
# menagerie
# susan
# oliver
# memories
# manipulated
# create
# worlds
# live
# encounter
# aliens
# concept
# centerpiece
# whole
# driven
# freed
# needs
# direct
# able
# hang
# lead
# gains
# speed
# intensifies
# really
# experience
# oscarcaliber
# unquestionably
# well
# throws
# humor
# president
# clinton
# cameos
# cleverly
# george
# forrest
# gump
# fact
# et
# al
# got
# trouble
# usage
# footage
# seen
# vis
# attended
# chuckles
# clintons
# muchdiscussed
# tension
# religion
# insightful
# already
# gone
# though
# helpful
# also
# senate
# hearing
# disappointing
# fitting
# memorial
# sagan
# sometime
# pedantic
# halls
# perhaps
# said
# dragons
# eden
# ingredients
# man
# amnesia
# wakes
# wanted
# murder
# dark
# city
# controlled
# beings
# mental
# powers
# synopsis
# woke
# suspected
# earth
# instead
# part
# experiment
# giant
# space
# intergalactic
# murdoch
# rufus
# sewell
# problem
# starts
# noir
# detective
# mystery
# hotel
# dead
# dame
# corner
# mysterious
# phone
# call
# tells
# heck
# soon
# enough
# chased
# murderous
# army
# pale
# black
# police
# dogged
# inspector
# bumstead
# william
# murderer
# missing
# tell
# searches
# wallet
# possible
# contacts
# clues
# fit
# confuse
# causes
# far
# question
# nature
# reality
# something
# fishy
# unreal
# always
# nobody
# remember
# morning
# leave
# nearby
# shell
# night
# around
# midnight
# notices
# enters
# state
# suspended
# animation
# creepy
# known
# strangers
# things
# inject
# fake
# peoples
# heads
# big
# hypodermic
# needles
# tune
# warp
# telepathic
# turns
# reason
# victim
# nightly
# human
# mutation
# possesses
# godlike
# abilities
# help
# scientist
# dr
# daniel
# schreber
# opinion
# alex
# proyas
# directed
# crow
# mentions
# press
# kit
# used
# spaceships
# blow
# cities
# think
# tired
# according
# interesting
# thing
# layers
# designed
# watch
# examine
# perspective
# main
# philosophical
# piece
# cinematic
# basically
# thinly
# disguised
# shootout
# humans
# whether
# klingons
# bugs
# proponents
# force
# books
# reaches
# beyond
# shootemup
# targets
# condition
# ethical
# true
# comic
# style
# order
# spawn
# batman
# mutant
# ninja
# turtles
# features
# showdown
# powerful
# asks
# worthy
# brazil
# blade
# runner
# philosophers
# screenplay
# filled
# unhappy
# peasants
# nearly
# aspect
# lives
# totalitarian
# military
# medieval
# regimes
# took
# refuge
# idea
# earthly
# suffering
# death
# heaven
# available
# meanwhile
# ideas
# prop
# head
# therefore
# sanctioned
# overturned
# came
# tumbling
# replaced
# democratic
# governments
# fear
# power
# experimentation
# darkly
# period
# writers
# freud
# kafka
# nietzsche
# dostoevsky
# pondered
# society
# place
# individual
# particular
# wrote
# lone
# hostile
# indifferent
# alienated
# dying
# defeated
# scientific
# experiments
# brains
# failed
# replies
# pointing
# isnt
# located
# indian
# courier
# became
# message
# carrying
# danger
# bear
# sean
# penn
# immature
# arrogant
# photographer
# punching
# loudmouth
# changed
# grown
# talents
# indication
# might
# imagine
# plenty
# ruthless
# rage
# showy
# machismo
# given
# charge
# bronson
# hopper
# struggle
# victories
# defeats
# simple
# lets
# unfold
# pace
# dictated
# unnecessary
# rush
# flash
# focus
# brothers
# david
# morse
# brother
# midwestern
# raised
# tending
# failing
# farm
# becoming
# officer
# viggo
# mortensen
# wild
# whose
# behavior
# reaction
# ancient
# pain
# cant
# name
# resolve
# returns
# vietnam
# coincidentally
# armed
# youth
# fleeing
# line
# becomes
# clear
# conflict
# threatens
# link
# shared
# plain
# sincere
# exactly
# perfect
# sincerity
# invested
# identify
# sickness
# destroys
# move
# faster
# handle
# problems
# budget
# stars
# pushed
# face
# im
# reviewing
# marketing
# others
# showing
# saw
# thought
# structure
# clean
# oversimplified
# sections
# obligatory
# seemed
# cliche
# going
# worth
# admission
# satirical
# usually
# categories
# longterm
# satire
# including
# jokes
# somehow
# related
# large
# scale
# strangelove
# situation
# themes
# derived
# unique
# wag
# dog
# necessarily
# either
# descriptions
# yet
# clever
# based
# original
# smart
# premise
# tend
# wander
# bit
# theres
# anything
# affects
# americans
# information
# weve
# media
# entertainment
# industry
# ways
# gotten
# point
# practically
# need
# bring
# news
# escapism
# counter
# thinking
# quickly
# establishing
# presents
# scenario
# coverage
# closely
# couldnt
# someone
# authority
# manipulate
# aspects
# conrad
# brean
# niro
# professional
# washington
# spin
# doctor
# restore
# presidents
# accused
# child
# molestation
# weeks
# election
# along
# top
# advisor
# ames
# heche
# fly
# california
# meet
# hotshot
# producer
# stanley
# motss
# hoffman
# pitch
# produce
# image
# war
# albania
# heard
# buy
# wheels
# motion
# riffing
# play
# inundated
# brings
# number
# experts
# manage
# folk
# singer
# visual
# effects
# technicians
# modern
# expert
# fad
# leary
# atmosphere
# numerous
# pop
# culture
# references
# relates
# tv
# dialogue
# witty
# funny
# actual
# gags
# crew
# filming
# actress
# portraying
# albanian
# refugee
# ordered
# kitten
# girl
# carry
# wound
# dozen
# different
# dogs
# since
# computerenhanced
# anyway
# ends
# bag
# inserted
# demonstrates
# relatively
# ordinary
# make
# oneliners
# humorous
# run
# actresss
# whenever
# emerges
# responding
# midpoint
# happen
# plot
# happens
# first
# act
# contains
# ten
# crops
# must
# deal
# fascinating
# actually
# deals
# headon
# realistic
# manners
# tendency
# avoid
# shift
# campaign
# false
# subject
# rolls
# situations
# started
# brilliant
# somewhat
# harmless
# conspiracy
# fool
# general
# public
# begins
# still
# quite
# montage
# entire
# flinging
# shoes
# trees
# honor
# sgt
# willie
# schumann
# hero
# concocted
# truly
# manages
# laugh
# afterwards
# succeeds
# respect
# retrospect
# done
# namely
# extending
# running
# filling
# valiant
# effort
# biggest
# cliches
# serial
# killer
# believable
# know
# suddenly
# spots
# clue
# reveals
# sure
# pretty
# describes
# kiss
# girls
# works
# overused
# personal
# rules
# goes
# giving
# rule
# applies
# highly
# psychologically
# stimulating
# wellcrafted
# screams
# unoriginality
# relies
# technical
# pull
# capable
# pulling
# add
# flaw
# covered
# unfortunately
# revealing
# insulting
# choices
# filmmakers
# seven
# knew
# put
# opening
# credits
# give
# actor
# credit
# throughout
# hidden
# waiting
# appear
# screen
# spoiled
# suspending
# knowledge
# plotwise
# almost
# originality
# introduced
# cross
# morgan
# freeman
# forensic
# psychologist
# immediately
# cliched
# gets
# woman
# husband
# threatening
# kill
# obviously
# getting
# gun
# forgotten
# next
# house
# told
# neice
# naomi
# gina
# ravera
# four
# days
# motivation
# chance
# relationship
# sympathize
# slightly
# introduction
# abducted
# kate
# mctiernan
# ashley
# judd
# traits
# target
# likes
# care
# making
# abduction
# suspenseful
# finds
# cell
# somewhere
# woods
# remembering
# gave
# certain
# decides
# calling
# casanova
# punish
# breaks
# escapes
# jumping
# waterfall
# found
# takes
# form
# leads
# search
# rest
# victims
# held
# captive
# many
# presume
# similarities
# intentional
# klass
# adapted
# novel
# written
# patterson
# worked
# aaron
# schneider
# reminiscient
# sometimes
# felt
# shots
# trying
# hard
# impress
# stunning
# unlike
# sunlight
# forest
# extremely
# way
# camera
# terrific
# chaotic
# cutting
# confusion
# judds
# experiencing
# todays
# similar
# freemans
# presence
# carries
# half
# carried
# promising
# dramatic
# handles
# scream
# underdeveloped
# members
# cary
# elwes
# portrays
# cop
# north
# carolina
# tony
# goldwyn
# lies
# phenomenal
# job
# year
# essential
# gary
# fleder
# controlling
# loses
# believability
# revelation
# losing
# blame
# falls
# developed
# lesser
# focuses
# screentime
# onedimensional
# revealed
# implausible
# thanks
# intelligent
# none
# conversations
# laughable
# seeming
# forced
# motive
# mainly
# casting
# killers
# rejection
# women
# assume
# monologue
# attractive
# friends
# shall
# admirer
# terror
# violence
# language
# suggested
# sex
# implausibilities
# mediocre
# thoroughly
# entertain
# urge
# performances
# adds
# tone
# script
# rely
# possibly
# convincing
# notch
# belt
# loved
# evil
# tense
# resolution
# anyone
# cheer
# nights
# summer
# deliciously
# commendable
# achievement
# considering
# season
# thus
# littered
# uneven
# fare
# heres
# genuinely
# fluff
# recognizes
# admittedly
# proud
# harrison
# ford
# broadly
# comedic
# plays
# sizeable
# concentrated
# easy
# forget
# counterpart
# anne
# deserves
# pat
# goofily
# difference
# fords
# heches
# matters
# click
# charged
# nobrainer
# gruff
# loveable
# island
# aviator
# quinn
# harris
# careerminded
# york
# magazine
# editor
# monroe
# tropical
# vacation
# fianc
# frank
# schwimmer
# assigned
# emergency
# photo
# shoot
# reluctantly
# hires
# plane
# crashes
# terrible
# stuck
# deserted
# paradise
# civilization
# series
# unpleasant
# hilarious
# choice
# unlikely
# odd
# couple
# resort
# tempted
# quinns
# shapely
# tagalong
# jacqueline
# subplot
# exists
# rooting
# pairing
# laughs
# eventually
# contrived
# distraction
# engrossing
# misadventures
# spends
# minor
# ivan
# reitman
# keeps
# brisk
# slim
# wears
# welcome
# title
# michael
# brownings
# allows
# notable
# taken
# context
# mean
# pirates
# essentially
# boils
# mishap
# theyre
# engaging
# serious
# played
# wink
# undeserved
# fire
# private
# ellen
# degeneres
# affect
# heterosexual
# shes
# lesbian
# naysayers
# proved
# wrong
# chemistry
# opposites
# attract
# utmost
# endearing
# electricity
# discussing
# likelihood
# several
# guesses
# fortyfive
# fifty
# whispers
# together
# ride
# historical
# shakespeare
# jesus
# christ
# explains
# bards
# materials
# source
# remakes
# rewrites
# inspiration
# dispute
# recent
# american
# contemporary
# wash
# shakespearean
# products
# upcoming
# midsummer
# dream
# shakespeares
# material
# cause
# productions
# change
# mrs
# brown
# madden
# bard
# vibrant
# love
# marc
# norman
# tom
# largely
# fantasy
# learns
# seriously
# wouldve
# married
# hathaway
# teenage
# young
# sons
# bachelor
# joseph
# fiennes
# struggling
# current
# romeo
# ethel
# christopher
# marlowe
# rupert
# everett
# viola
# lesseps
# gwyneth
# paltrow
# changes
# writes
# greatest
# tragedies
# juliet
# loosely
# parallels
# effect
# develop
# sexy
# momentum
# smoothes
# bumps
# unfinished
# unsuccessful
# geoffrey
# wills
# worrisome
# agent
# philip
# wilkinson
# hugh
# ben
# affleck
# leading
# troupe
# favorable
# impression
# judi
# dench
# lends
# brief
# queen
# elizabeth
# standout
# creating
# percentage
# vibrance
# dangerous
# flirts
# breezy
# lighthearted
# accessible
# audiences
# lowest
# common
# denominator
# everyone
# prime
# date
# flick
# inspiring
# regard
# revels
# wholesome
# wellrounded
# absent
# recommendable
# traditional
# slew
# releases
# secrets
# innocent
# cute
# frances
# boyd
# impacting
# affecting
# mobile
# ramsey
# medical
# researcher
# working
# corporation
# called
# striving
# patent
# become
# recognized
# artist
# wife
# lillian
# miriam
# stands
# behind
# suppressing
# natural
# artistic
# tendencies
# marriage
# greater
# implication
# deadly
# political
# corporations
# business
# bottom
# receiving
# grant
# study
# therapy
# hoping
# spent
# away
# intensity
# romance
# dwindling
# threeyear
# shaky
# slyly
# managed
# keep
# secretive
# locking
# lab
# limits
# secretly
# conducting
# rats
# mice
# benefit
# humanity
# treatments
# cures
# argument
# wants
# want
# hear
# animals
# benefits
# depicted
# monster
# frankenstein
# created
# skewed
# opposed
# cares
# farmer
# represented
# gentleman
# vine
# chooses
# farmers
# organic
# farming
# hired
# university
# monitor
# dangers
# pesticides
# chemicals
# use
# survive
# financially
# irreparable
# harm
# consumer
# health
# risks
# attached
# methods
# thirty
# companies
# enhance
# profit
# margins
# view
# artists
# points
# shown
# constantly
# shouldnt
# argues
# questioning
# completely
# ignored
# ahead
# bogged
# bureaucrats
# firm
# fail
# chimps
# companys
# higher
# ups
# argue
# wait
# longer
# animal
# trap
# countryside
# catches
# chester
# gorgeous
# pet
# means
# saved
# trapped
# seat
# car
# spotted
# coworkers
# nervously
# invites
# dinner
# afraid
# spot
# rushes
# area
# flatly
# nevertheless
# heart
# speak
# represent
# eat
# meat
# radical
# scientists
# eschewed
# politically
# correct
# rational
# highlighting
# reacts
# emotional
# mostly
# davids
# coming
# angle
# puppets
# strings
# spewed
# generalized
# philosophies
# directors
# beside
# lost
# likened
# hideous
# holds
# ground
# ensuring
# plant
# stability
# muse
# poetry
# art
# goodness
# beauty
# spending
# share
# views
# physically
# attracted
# ripe
# affair
# alexs
# apartment
# suspicious
# considers
# enemy
# apart
# cunning
# tricks
# possess
# impossible
# remain
# disintegrated
# feeling
# lonely
# discovered
# deplorable
# shocking
# mercifully
# dies
# walk
# fails
# respond
# loving
# gesture
# stay
# opting
# tortured
# knocks
# cold
# conversation
# progress
# expect
# extinct
# answers
# answered
# natives
# vision
# entrusted
# enrich
# creations
# peaceful
# opinions
# deeper
# arguments
# shame
# decent
# tried
# loudly
# trusting
# catch
# white
# telling
# harmful
# trends
# sees
# didactic
# listening
# lecture
# rebel
# truth
# prefer
# presented
# metaphorically
# considerable
# merit
# shortcomings
# seeing
# statements
# effective
# setting
# intense
# needed
# show
# currently
# differ
# neutral
# indifference
# stakes
# ecological
# statement
# cow
# painting
# faces
# envisioned
# horrors
# unspoken
# mistake
# fence
# forgets
# desires
# stares
# song
# blares
# background
# learned
# brutalized
# raw
# pertinent
# requires
# answer
# resolved
# consumers
# caught
# changing
# happily
# surprise
# ridley
# sequel
# inevitable
# reviewer
# handing
# chair
# box
# office
# gem
# cameron
# previous
# ii
# surprisingly
# dull
# terminator
# immense
# proportions
# alters
# results
# terrifying
# ever
# unprepared
# theaters
# wish
# fright
# unimaginable
# literally
# shrieking
# added
# testosterone
# pumping
# sequels
# tops
# heroine
# sympathetic
# sigourney
# weaver
# placing
# suitable
# ended
# lieutenant
# ripley
# hypersleep
# nostromo
# awakened
# survivor
# past
# company
# doubtful
# explain
# colony
# families
# flourishing
# planet
# despite
# stern
# warnings
# remains
# rigid
# wont
# ripleys
# feasible
# carter
# burke
# reiser
# gather
# team
# travel
# includes
# buff
# jenette
# goldstein
# questionable
# hicks
# biehn
# loyal
# android
# bishop
# lance
# henriksen
# tags
# locate
# arriving
# extinguished
# environment
# rebecca
# newt
# carrie
# henn
# mother
# surrogate
# happened
# hell
# loose
# multiplies
# thrills
# suspense
# scotts
# focused
# systematically
# member
# jettison
# race
# chills
# incredibly
# heightened
# judgment
# topping
# renny
# harlin
# cliffhanger
# astonishing
# endings
# climax
# extreme
# recall
# sustain
# dropping
# occur
# seemingly
# endless
# conclusion
# history
# steps
# lifting
# machines
# fight
# flawless
# special
# exhausting
# drained
# anxiety
# properly
# decade
# release
# seamless
# overlooked
# horner
# oscar
# nomination
# scores
# odyssey
# compilation
# wellknown
# composers
# design
# incredible
# snag
# corridors
# lit
# red
# amount
# arises
# welllit
# locations
# normally
# scare
# uses
# feeds
# scariest
# involve
# average
# received
# portrayal
# incorporating
# sympathy
# hardedged
# persona
# soars
# developing
# threedimensional
# quiet
# attitude
# androids
# flat
# fair
# enthusiasm
# personality
# annoying
# nice
# sleazy
# corporate
# tvs
# mad
# bill
# paxton
# hope
# highlights
# rightfully
# gore
# sort
# pumps
# directs
# proves
# horrific
# technically
# aside
# werent
# born
# rock
# rolled
# monterey
# affectionate
# glimpse
# influenced
# hippies
# otis
# redding
# jimi
# hendrix
# janis
# joplin
# mamas
# papas
# jefferson
# airplane
# documentary
# jampacked
# contagious
# energy
# warning
# reveal
# outdoor
# concert
# defies
# stereotype
# population
# painted
# smoke
# joints
# moon
# broadway
# broad
# spectrum
# matter
# talented
# musicians
# stir
# soul
# excitement
# cleaning
# thousands
# seats
# asked
# interviewer
# lucky
# organized
# craziness
# phillips
# leader
# tries
# touch
# band
# tuning
# remarks
# system
# vanity
# appreciation
# street
# interaction
# performer
# continues
# infectious
# tear
# eyes
# belts
# ballad
# ball
# chain
# lyrics
# complicated
# mime
# guitar
# captivating
# singing
# recognize
# stage
# enthralled
# sitting
# drawback
# bands
# names
# approximately
# contrast
# wholly
# forgettable
# chunk
# acts
# precious
# rare
# sway
# variety
# beautifully
# immersed
# depressing
# backstreet
# boys
# jennifer
# lopez
# modeling
# shaking
# arent
# thrill
# rides
# future
# exceptions
# spirit
# full
# cliff
# hangers
# doc
# lloyd
# marty
# fox
# shue
# travelling
# jennifers
# incident
# jr
# says
# yes
# wilson
# whoever
# tends
# repeat
# wasnt
# joking
# endured
# exciting
# parody
# everythings
# plan
# conflicts
# direction
# bother
# list
# etc
# alternate
# happening
# stops
# breath
# occurred
# difficult
# convey
# zany
# describing
# sacrificed
# grand
# finale
# lots
# normal
# gratuitous
# adventure
# lacks
# charm
# dominate
# predecessor
# wednesday
# march
# investigation
# underway
# charlotte
# south
# crime
# prostitute
# renee
# zellweger
# brutally
# slain
# severed
# body
# train
# station
# trunk
# harbor
# miles
# duo
# braxton
# chris
# kennesaw
# rooker
# strapped
# wayland
# tim
# roth
# wealthy
# unemployed
# genius
# graduated
# cum
# princeton
# appears
# commit
# heinous
# deceiver
# thriller
# pate
# jonas
# josh
# mark
# sundance
# grave
# game
# intellectually
# cops
# captions
# proceedings
# waylands
# iq
# kennesaws
# interrogation
# lie
# detector
# test
# drama
# among
# escalates
# inevitably
# elements
# thrown
# measure
# suffers
# peculiar
# stressful
# render
# virtually
# catatonic
# violent
# compulsive
# gambler
# deep
# debt
# syndicate
# haunted
# abusive
# delights
# terrorizing
# rosanna
# arquette
# suspects
# unfaithful
# foibles
# failings
# brought
# elizabeths
# deepens
# unclear
# upper
# hand
# transpires
# dimlylit
# involves
# feel
# mamet
# edgy
# claustrophobic
# explosive
# pivotal
# confrontation
# riveting
# succumbs
# throw
# unexpected
# twist
# shock
# viewers
# stretches
# credulity
# raises
# carefully
# implications
# logic
# procedure
# totally
# accept
# criminal
# proceed
# manner
# occasionally
# instances
# primarily
# flashbacks
# featuring
# pates
# employ
# techniques
# present
# vignettes
# final
# hours
# intriguing
# unreliable
# narrator
# underlining
# voiceover
# visually
# dismissed
# gimmicks
# fashioned
# drips
# stylistic
# touches
# oldfashioned
# rotary
# models
# cinematographer
# butler
# unconventional
# liven
# light
# shadow
# exceptionally
# lazy
# treading
# overacting
# troubled
# hes
# types
# penns
# uninspired
# rookers
# turned
# starmaking
# turn
# jerry
# maguire
# note
# vulnerability
# easily
# caricature
# solid
# parks
# delivers
# psychiatrist
# whos
# talks
# hammered
# weaknesses
# spelled
# bold
# letters
# increasingly
# characteristic
# makers
# gripping
# uninteresting
# brian
# depalma
# badly
# scoring
# untouchables
# casualties
# raising
# cain
# disastrous
# bonfire
# vanities
# flames
# consequently
# carlitos
# shrewd
# commercial
# reteaming
# pacino
# scarface
# returning
# gangland
# yielded
# successes
# dynamite
# hampered
# depalmas
# excesses
# cannibalism
# carlito
# brigante
# lifelong
# unexpectedly
# released
# prison
# serving
# five
# sentence
# conviction
# technicality
# declares
# reformed
# streets
# determined
# fulfill
# buying
# rental
# bahamas
# conversion
# kleinfeld
# crooked
# attorney
# childhood
# friend
# bodyguard
# luis
# guzman
# flame
# gail
# penelope
# ann
# miller
# ready
# retire
# peace
# associates
# step
# shake
# strongest
# outstanding
# accompanies
# cousin
# drug
# pulse
# edge
# closes
# thrilling
# subway
# central
# highlight
# gift
# choreographed
# mayhem
# occasions
# flows
# freely
# viscera
# compelling
# corleone
# aging
# gangster
# unsuccessfully
# culmination
# godfather
# saga
# opera
# immediacy
# everpresent
# doom
# launched
# flashback
# observes
# attempt
# straight
# function
# wind
# captures
# dilemma
# cautious
# observation
# turning
# jew
# rican
# italian
# wiseguys
# outsider
# huge
# chip
# shoulder
# pathetic
# drinker
# cocaine
# addict
# tough
# league
# invests
# nervous
# overwhelming
# survival
# instinct
# steadily
# brink
# jolting
# profound
# deja
# vu
# steal
# shamelessly
# adding
# scorsese
# repertoire
# tracking
# passing
# goodfellas
# recycles
# degree
# swing
# vertigo
# via
# double
# climactic
# strike
# reminiscent
# standpoint
# longsuffering
# girlfriend
# limited
# integrated
# fully
# easier
# forgiving
# superficial
# flaws
# backbone
# principle
# iron
# grip
# thievery
# tragic
# deliberate
# confident
# willing
# rewarded
# jekyll
# hyde
# maids
# word
# cheery
# louis
# dreary
# dismal
# malkovich
# terminally
# depressed
# desperate
# mary
# reilly
# julia
# roberts
# monstrous
# abuse
# sentiment
# fears
# london
# slums
# marvel
# survived
# lighting
# exceedingly
# low
# liquid
# flow
# honey
# oozing
# strawberry
# moody
# shocked
# theater
# matinee
# adjust
# sunny
# skies
# afterward
# archetypes
# person
# components
# cerebral
# intellectual
# powerless
# alter
# ego
# forceful
# conscience
# neither
# functioning
# separated
# disaster
# differences
# accomplished
# demeanor
# transformation
# thrust
# realm
# psychological
# horror
# demands
# skillful
# suitably
# melancholy
# glenn
# close
# lips
# madam
# apparently
# frequents
# cardboard
# cutout
# filmmaking
# craft
# upbeat
# apocalypse
# hearts
# darkness
# striking
# depiction
# debate
# surrounded
# antiwar
# addition
# extremes
# disturbing
# corruption
# devastating
# follows
# mission
# captain
# benjamin
# willard
# martin
# sheen
# seek
# eliminate
# colonel
# kurtz
# green
# insane
# militant
# base
# cambodia
# assassinate
# prejudice
# deemed
# accepts
# pondering
# accusation
# accusing
# speeding
# tickets
# indy
# puts
# escorting
# group
# operate
# chef
# frederic
# chief
# albert
# hall
# johnson
# mr
# fifteen
# yearold
# laurence
# fishburne
# bizarre
# infamous
# eccentric
# duvall
# kilgore
# attack
# overtake
# surf
# inspired
# famed
# surfer
# duvalls
# quotes
# frightening
# community
# strange
# everywhere
# followers
# freelance
# dennis
# attempts
# cannot
# understand
# madness
# encompasses
# aware
# willards
# refers
# boy
# sent
# grocery
# clerks
# collect
# intent
# completing
# corresponds
# epic
# controversial
# ravages
# definitely
# miss
# prepared
# bigtime
# mommas
# mothers
# crib
# babies
# visits
# goal
# goals
# boyfriend
# girlfriends
# realizing
# jerk
# grow
# bow
# critique
# aint
# relationships
# friendship
# maturity
# growing
# stuff
# inability
# responsibilities
# wellwritten
# ive
# superb
# granted
# slow
# glad
# pass
# adulthood
# grander
# theme
# passed
# yeah
# momma
# events
# went
# oh
# record
# zero
# damn
# crackin
# setup
# comedies
# daytoday
# relate
# ving
# rhames
# drinking
# kitchen
# infamously
# improvised
# african
# gotta
# established
# dude
# scared
# shit
# outta
# gibson
# rb
# mtv
# hmmmm
# uncanny
# resemblance
# taye
# diggs
# nailed
# tee
# glued
# molded
# shaped
# hoped
# gibsons
# henson
# backer
# helped
# levels
# authentic
# issues
# struggles
# hopes
# masterfully
# acted
# homage
# boyz
# singleton
# pulled
# companion
# followup
# baby
# wanna
# omar
# gooding
# cuba
# younger
# starred
# wheres
# joblo
# shaft
# cooking
# completly
# unknown
# spread
# fred
# doug
# howie
# reaching
# suburb
# mortgage
# pay
# thursday
# evenings
# bar
# boss
# arrangements
# mistress
# downtown
# spend
# staff
# meetings
# split
# decide
# kathy
# honest
# sociology
# student
# writing
# thesis
# suburban
# male
# species
# believes
# paper
# ok
# rendezvous
# stays
# waist
# precise
# neck
# claims
# censorship
# board
# sweden
# kim
# novak
# garner
# playboy
# howard
# morris
# accountant
# diet
# support
# randall
# investment
# afford
# blacks
# count
# kensington
# austin
# looked
# journey
# anticipated
# sleeper
# brim
# uproarious
# lurid
# toilet
# keel
# hilarity
# mike
# myers
# swinging
# spy
# bald
# headed
# spotlight
# son
# seth
# springer
# segment
# entitled
# dad
# hosted
# talkshow
# spoofing
# oprah
# kathie
# lee
# exception
# guests
# sample
# stitches
# assisted
# minime
# verne
# troyer
# pintsized
# clone
# awry
# fan
# ask
# mimicking
# mindy
# sterling
# frau
# farbissina
# evils
# assassin
# sidekick
# treated
# liaison
# underground
# bedroom
# chamber
# coffee
# machine
# awkwardness
# expressed
# honeymoon
# vanessa
# hurley
# disastrously
# thwart
# diabolical
# plans
# cryogenic
# freezing
# enabled
# hop
# periods
# crazy
# austins
# mojo
# jumps
# portal
# employs
# grotesque
# scottish
# named
# fat
# bastard
# commandeer
# informed
# wrongdoing
# exposition
# supplied
# timetraveling
# device
# volkswagen
# beetle
# foxy
# cia
# operative
# felicity
# shagwell
# heather
# graham
# destroy
# dc
# jabs
# wars
# calls
# complete
# joke
# shagged
# boasted
# scattershot
# hitandmiss
# knack
# delivering
# quits
# involving
# ferrell
# refusal
# wagner
# patterns
# voice
# movements
# recycled
# kristen
# johnston
# ivana
# humpalot
# unfunny
# rendition
# dedication
# project
# bits
# extended
# gag
# tent
# shadows
# imagination
# merely
# okay
# gungho
# enjoyable
# bathroom
# talk
# severe
# complaint
# bigglesworth
# teeth
# fans
# disappointed
# riot
# foresee
# installments
# collection
# quota
# fresh
# jamey
# hughton
# weekly
# column
# november
# awards
# december
# crossgates
# mall
# guilderland
# ny
# matt
# perreault
# sister
# jena
# free
# paid
# passes
# perils
# excessive
# non
# stop
# pushing
# tomorrow
# sequences
# foreshadow
# foot
# selfaware
# enclosed
# warship
# crossing
# unfriendly
# chinese
# waters
# definite
# party
# manipulating
# sides
# introduces
# brosnon
# portrayed
# outandout
# singlehandedly
# terrorists
# escape
# nick
# flying
# fighter
# jet
# strangle
# terrorist
# notorious
# payoff
# obvious
# processes
# apologizing
# hysterical
# emphasis
# placed
# villains
# thrillers
# correctness
# behalf
# term
# sounds
# kudos
# plausible
# jonathon
# pryce
# elliot
# carver
# mogul
# massive
# empire
# nuclear
# weapons
# english
# ministry
# defense
# brewing
# southern
# asian
# seas
# accurately
# cover
# detailed
# specific
# hook
# cool
# gadgets
# investigate
# jam
# concentrates
# wai
# lin
# yeoh
# spite
# goons
# balance
# stunts
# cartoony
# plausibility
# issue
# brightest
# blockbuster
# hits
# trashed
# critics
# tons
# money
# tradition
# update
# universal
# mummy
# sucker
# critic
# extravaganza
# brendan
# fraser
# adventurous
# explorer
# rick
# oconnell
# teams
# curious
# clumsy
# librarian
# evelyn
# rachel
# weisz
# hamunaptra
# loves
# egypt
# visit
# fable
# claimed
# battle
# chose
# jonathan
# hannah
# doors
# uncover
# reads
# egyptian
# imhotep
# arnold
# vosloo
# alive
# opened
# read
# curses
# launching
# unbelievable
# forces
# furious
# awoke
# campy
# type
# favorites
# corny
# dazzled
# rising
# desert
# swarms
# beetles
# locusts
# creatures
# crawling
# skin
# episode
# phantom
# menace
# disneys
# jungle
# gods
# monsters
# teens
# blast
# reminded
# talked
# likable
# didnt
# genres
# mixed
# mixing
# potential
# pure
# mix
# purely
# amazing
# depicting
# mummies
# treasures
# egyptians
# costume
# outfits
# troops
# costumes
# morals
# unwritten
# laws
# follow
# naturally
# preconceived
# notions
# accomplish
# secondly
# wed
# dumb
# viewing
# expecting
# assuming
# grudge
# disney
# merchandising
# ploy
# jim
# carreys
# gonna
# stink
# biased
# viewpoint
# lines
# credibility
# comparisons
# jackie
# comparison
# pulp
# quentin
# tarantino
# joe
# jane
# taking
# account
# integrity
# bored
# sooooo
# cheezy
# describe
# contradictions
# weigh
# balanced
# important
# boring
# amateurish
# philosophy
# reflecting
# responsible
# pam
# grier
# blaxploitation
# comeback
# tarantinos
# travoltas
# sudden
# revival
# thru
# airline
# stewardess
# extra
# cash
# revenue
# smuggling
# sums
# united
# states
# ordell
# robbie
# fictions
# samuel
# jackson
# illegal
# firearms
# enlisted
# aid
# gara
# bank
# robber
# scheme
# million
# dollars
# stopped
# atf
# ray
# nicolet
# keaton
# custody
# possession
# narcotics
# allowed
# airport
# obstacle
# ordells
# friendly
# intended
# posts
# jackies
# bail
# bars
# learn
# actions
# tight
# squeeze
# twice
# compromise
# authorities
# evidence
# provided
# ensues
# storytelling
# law
# veteran
# forster
# max
# cherry
# maxs
# fondness
# major
# benefactor
# beat
# depth
# melanie
# bridget
# fonda
# ditzy
# sun
# bleached
# babe
# bong
# thin
# otherwise
# bouquet
# wasted
# crook
# bucks
# hardly
# speaks
# compared
# irrelevant
# lifelike
# whereas
# suffered
# specifically
# reversed
# sadly
# perception
# chemical
# awesome
# rambling
# hitman
# couldve
# remained
# forever
# putting
# deter
# fond
# recollections
# beginning
# griers
# progresses
# pouring
# anxious
# partake
# quirky
# directing
# silver
# adaption
# elmore
# leonards
# rum
# punch
# moviegoers
# satisfied
# oozes
# brash
# qualities
# icon
# toned
# splitscreen
# devices
# replayed
# multiple
# viewpoints
# began
# revolutionary
# conservative
# satiate
# realize
# knock
# socks
# happy
# massage
# feet
# anatomy
# cements
# forefront
# feature
# latest
# animated
# mulan
# adheres
# formula
# nonetheless
# adults
# fa
# mingna
# wen
# lea
# salonga
# dutiful
# customs
# quietly
# approval
# matchmaker
# margoyles
# speaking
# horizon
# huns
# led
# shanyu
# miguel
# ferrer
# invading
# china
# emperor
# morita
# decreed
# donate
# serve
# mulans
# father
# zhou
# soontek
# leg
# fate
# save
# fathers
# masquerading
# battlefield
# assumed
# ping
# camp
# bumbling
# recruits
# yao
# harvey
# fierstein
# ling
# gedde
# watanabe
# trained
# shang
# wong
# donny
# osmond
# alone
# tasks
# fashion
# companions
# horse
# khan
# cricket
# guardian
# dragon
# mushu
# eddie
# murphy
# hunchback
# notre
# lukewarm
# occasional
# relief
# geared
# overdoes
# overdose
# powerfully
# schizophrenic
# commentary
# formulaic
# additions
# regrettable
# par
# aweinspiring
# musical
# songs
# subjected
# boasts
# highest
# toll
# cartoon
# killing
# offscreen
# mom
# graphic
# resides
# snugly
# slaughter
# armies
# ironic
# strict
# adherence
# guts
# lessen
# ax
# compulsory
# remove
# unrealistic
# deliver
# trailer
# cauldron
# pinocchio
# opens
# menacing
# mist
# land
# prydain
# captured
# centuries
# conjure
# deathless
# warriors
# dallben
# apprentice
# taran
# dreams
# warrior
# pigkeeper
# pig
# hen
# warm
# bath
# realizes
# wens
# thoughts
# bucket
# water
# hide
# ruler
# horned
# searching
# location
# mischievous
# creature
# gurgi
# dismay
# besides
# stole
# apple
# hears
# squeal
# races
# rescue
# kidnapped
# dragonlike
# gwythants
# chases
# staring
# kings
# castle
# climbs
# walls
# dungeon
# princess
# eilonwy
# magic
# burial
# fflewdurr
# flamm
# harp
# reappears
# claiming
# trail
# tracks
# sucked
# fairfolk
# reunited
# devises
# prevent
# destroying
# grumpy
# doli
# travelers
# cottage
# comically
# witches
# inhabit
# agree
# exchange
# agrees
# destroyed
# living
# climb
# return
# worse
# henchmen
# capture
# unleashes
# supernatural
# rescues
# jump
# wanting
# decay
# kicks
# magically
# selfdestructs
# reappear
# useless
# saying
# bargain
# response
# offer
# trade
# lifeless
# heartbroken
# arms
# await
# triumphant
# spectacular
# ron
# fired
# position
# chairman
# walt
# bought
# alexander
# sorcery
# studio
# bringing
# studios
# executive
# promised
# projects
# eisner
# executives
# arrived
# animators
# rocky
# retired
# originally
# budgeted
# costs
# constant
# june
# praising
# reviews
# flopped
# pg
# disneyfied
# alexanders
# chronicles
# scarier
# darker
# efforts
# rescuers
# hound
# scary
# stayed
# rejected
# unmemorable
# whatever
# grossing
# failure
# grounded
# exiled
# buildings
# reputation
# mouse
# grossed
# mermaid
# regain
# successful
# rereleased
# temporary
# locked
# vault
# denied
# vista
# requesting
# september
# kingdom
# imported
# england
# converted
# ntsc
# hadnt
# included
# treat
# bootleg
# copies
# noticed
# seconds
# ghoulish
# looking
# skeletons
# trimmed
# uk
# kinda
# online
# diehard
# signed
# decided
# rumors
# announced
# criticisms
# thirteen
# asking
# filmgoers
# alike
# assistant
# keeper
# storys
# likeable
# opposite
# brave
# lesson
# lovable
# uh
# henchman
# dwarf
# creeper
# phil
# imaginative
# sinister
# voiced
# gruesomely
# sidekicks
# spunky
# wicked
# secret
# pleasant
# rounded
# quest
# mystical
# hooking
# elmer
# bernsteins
# calming
# darkest
# rises
# overall
# endeavor
# unfamiliar
# kick
# stampede
# lion
# observing
# fires
# disappeared
# achieved
# achievements
# palmetto
# sweat
# fill
# erie
# sensuality
# farce
# humid
# nurtures
# modestly
# absurd
# edginess
# winks
# havent
# patient
# spins
# twists
# harry
# barber
# woody
# harrelson
# served
# harbors
# animosity
# obtuse
# officials
# harrys
# sculptor
# nina
# gershon
# eye
# rhea
# malroux
# elisabeth
# millionaire
# proposes
# thatll
# staged
# stepdaughter
# odette
# chloe
# sevigny
# coos
# attributed
# oscarnominated
# las
# vegas
# foreshadowing
# shues
# seductive
# delight
# pulls
# barbara
# swanson
# combo
# admirable
# relish
# ensemble
# slutty
# teen
# tease
# bound
# showgirls
# vs
# larry
# flynt
# grievances
# harrelsons
# narration
# needless
# suppose
# gershons
# cries
# meatier
# ultimately
# plots
# angles
# unstable
# reproach
# laughed
# tacked
# liveaction
# framed
# roger
# rabbit
# questioned
# juicy
# nifty
# volker
# schlondorff
# summers
# tin
# drum
# smoothly
# shocks
# abortion
# incest
# prominent
# sensitive
# delicate
# cider
# harsh
# substantial
# shine
# homer
# wells
# tobey
# devil
# orphan
# infant
# adoptive
# grows
# tutelage
# wilbur
# larch
# caine
# orphans
# st
# cloud
# obstetrician
# unhappily
# pregnant
# seeking
# figuring
# orphanage
# teaching
# obstetrics
# refuses
# perform
# abortions
# wondering
# couples
# behave
# experienced
# youthful
# ideals
# expectations
# insulated
# upbringing
# skilled
# procedures
# woefully
# naive
# ignorant
# befriending
# hitches
# landing
# migrant
# workers
# orchard
# lived
# worldly
# candy
# charlize
# theron
# astronauts
# tutor
# inherently
# lifes
# unaware
# strength
# thoughtful
# curiosity
# appealing
# caring
# caretaker
# princes
# maine
# ritualistic
# goodnight
# communicate
# commitment
# maudlin
# saccharine
# delroy
# lindo
# rose
# pickers
# joins
# lasse
# hallstrom
# eating
# gilbert
# grape
# irving
# garp
# deserve
# regardless
# divisive
# offended
# evenhanded
# treatment
# reference
# posted
# quarters
# illiterate
# apply
# ignore
# similarly
# reasoning
# god
# followed
# promise
# continue
# preferring
# trust
# lord
# thine
# lean
# unto
# understanding
# proverbs
# kjv
# builder
# designers
# blueprint
# conductor
# architect
# blessing
# splash
# festival
# plagued
# earnestly
# shallow
# genx
# angst
# angered
# spark
# hype
# waited
# calmly
# wherein
# reside
# checked
# fuss
# dating
# uninitiated
# newcomers
# eckhart
# malloy
# chad
# drones
# dispatched
# nameless
# remote
# branch
# week
# assignment
# examples
# doubt
# blond
# golden
# genetically
# engineered
# charmer
# glide
# effortlessly
# ladder
# chads
# weaker
# practitioner
# persistence
# talent
# awaiting
# flight
# drab
# lounge
# suggests
# vulnerable
# woo
# simultaneously
# dump
# recently
# dumped
# route
# revenge
# itll
# dignity
# helpless
# prey
# christine
# stacy
# edwards
# fragile
# deaf
# temp
# moves
# flashing
# lunch
# flowers
# hamhanded
# flattered
# eligible
# dates
# guess
# triangle
# develops
# grounds
# handicapped
# shy
# wretched
# settle
# adult
# social
# junior
# writerdirector
# labute
# chilling
# committed
# souls
# stunned
# disbelief
# humiliates
# subordinates
# venom
# christines
# chillingly
# weakness
# postal
# handguns
# playground
# guise
# allegory
# succeed
# prove
# racism
# fraught
# peril
# representative
# meek
# cruelty
# careful
# manipulation
# symbol
# unbridled
# capitalism
# greed
# metaphor
# labutes
# multilayered
# disturb
# entirely
# darned
# mens
# demonstrate
# lengths
# hold
# engaged
# basic
# bodily
# necessity
# ciphers
# measured
# likewise
# sum
# youve
# met
# genuine
# classify
# conventional
# mesmerizing
# craftsmanship
# offers
# myriad
# triumph
# gates
# merciless
# satisfaction
# steve
# jobs
# cavemans
# valentine
# aunjanue
# ellis
# tamara
# tunie
# dawes
# kasi
# lemmons
# dvd
# plus
# annual
# toronto
# international
# freak
# http
# filmfreakcentral
# net
# engine
# mixture
# basquiat
# angel
# dave
# asylum
# feverish
# homeless
# february
# discovers
# cave
# ella
# fruit
# crotch
# murdered
# believing
# imagined
# nemesis
# shooting
# rays
# atop
# chrysler
# romulus
# avantgarde
# colm
# sleuthing
# interrupted
# delusional
# bouts
# ecstasy
# creation
# pianist
# prior
# psychosis
# uncovers
# harasses
# solve
# highprofile
# workshop
# fits
# mundane
# todd
# mcfarlanes
# urban
# spiritual
# guide
# divergent
# network
# informants
# supporters
# wickedly
# colourful
# archenemy
# piles
# dizzying
# slapdash
# colours
# lavish
# extent
# vaguely
# surprised
# blue
# cars
# gotham
# heroic
# audacity
# portray
# staining
# virgin
# snow
# expanding
# shape
# difficulties
# spring
# misunderstanding
# conventions
# superhero
# attacking
# entrenched
# ruling
# classes
# government
# arts
# legend
# royal
# birth
# comforts
# favour
# existence
# park
# mythology
# signs
# twelve
# vultures
# carrion
# birds
# nation
# novelist
# upon
# franchise
# misunderstood
# shyamalans
# unbreakable
# mature
# extrapolation
# format
# millers
# seminal
# knight
# redefined
# medium
# ruminations
# sticky
# topics
# readers
# maxx
# mtvs
# shortlived
# adaptation
# errant
# twisted
# forgetting
# backlash
# americas
# contributions
# saturated
# virtuoso
# grace
# amy
# vincent
# venice
# ca
# inhabiting
# practical
# following
# debut
# eves
# bayou
# realities
# mysticism
# fulfills
# elegant
# expression
# landscape
# taste
# approached
# paradigm
# intensely
# archetype
# postmodern
# wool
# trench
# coats
# tights
# capes
# courageous
# delirious
# yammering
# idiot
# savant
# truest
# chaos
# alley
# wasteland
# pie
# acknowledges
# laid
# heroes
# biggs
# chronic
# kev
# nicholas
# desperately
# reid
# oz
# klein
# lacrosse
# player
# finch
# kaye
# thomas
# crass
# nickname
# pays
# classmate
# rumours
# size
# attend
# michigan
# impossibly
# horny
# studly
# stiflers
# seann
# sharpest
# sexually
# unsatisfied
# quartet
# pact
# lose
# prom
# nerds
# revolves
# makin
# whoopee
# ogled
# alyson
# perky
# bunch
# abound
# defy
# arouse
# andor
# amuse
# adolescent
# shannon
# internet
# raucous
# guiltily
# pleasurable
# jims
# lusty
# hot
# differentiates
# dirty
# eighties
# nineties
# obsession
# fluids
# standouts
# sctv
# eugene
# levy
# kindhearted
# athlete
# row
# paynes
# underappreciated
# disarmingly
# levys
# crowdpleasing
# expressive
# brow
# emulate
# flicks
# skillfully
# tunes
# hughes
# breakfast
# club
# evidently
# covers
# minds
# healthy
# safe
# pies
# whip
# condom
# socially
# raunch
# familiarity
# charming
# recommend
# buzz
# fresher
# heap
# warn
# derek
# zoolander
# impressionable
# minister
# abolish
# labor
# deed
# stupid
# pretend
# idiotic
# premises
# ideal
# circumstance
# relax
# frivolous
# youre
# mindless
# stiller
# assembled
# subjective
# personally
# enjoyed
# cracked
# unrestrained
# whipping
# snap
# celebrity
# dozens
# vince
# vaughn
# billy
# zane
# winona
# ryder
# christian
# slater
# duchovny
# natalie
# portman
# andy
# dicks
# makeover
# masseuse
# particulars
# fancy
# orgy
# taylor
# countries
# zeroing
# missteps
# pissed
# gas
# adored
# bowie
# judge
# appreciated
# moronic
# merman
# dare
# monkey
# soundtrack
# zagged
# rhythm
# enjoy
# quips
# skip
# bird
# rent
# influence
# deuce
# bigalow
# freddy
# fingered
# jay
# silent
# bob
# dirt
# indecent
# proposal
# redford
# wise
# onscreen
# proven
# bigger
# helmed
# combining
# um
# realism
# river
# chagrin
# quiz
# dazzling
# energetic
# whisperer
# represents
# directorial
# subgenre
# scenery
# scottthomas
# annie
# maclean
# uptight
# respected
# johanssen
# climaxes
# horses
# colliding
# semi
# graces
# barely
# misery
# heals
# mend
# montana
# booker
# busy
# neill
# ranch
# toms
# falling
# trainer
# delicately
# lyrical
# ear
# synonymous
# honesty
# refreshing
# consistently
# mountain
# vistas
# yorkers
# spell
# richardsons
# photography
# casts
# gimmicky
# technique
# switch
# ratio
# squarish
# widescreen
# underrated
# heartfelt
# emotive
# niceguy
# sexist
# lout
# shortcut
# explaining
# cheating
# spouses
# wouldbe
# fish
# air
# luckily
# curiously
# textured
# adultery
# afterthought
# ties
# complex
# mars
# attacks
# deranged
# burtons
# invasion
# breathtaking
# equal
# counts
# gleefully
# blasting
# unsavory
# trading
# cards
# cues
# sources
# independence
# bigbudget
# extravaganzas
# painfully
# appeal
# america
# celebrated
# greedy
# hapless
# splendid
# swarm
# saucers
# storms
# solar
# formation
# spinning
# metal
# appearance
# combination
# danny
# elfmans
# thundering
# jawdropping
# swear
# breathing
# lays
# resplendent
# cape
# television
# broadcast
# earthlings
# regularly
# scheduled
# programming
# mildly
# drawing
# burton
# belongs
# caricatures
# jack
# nicholson
# fizzles
# developer
# rod
# steiger
# amusing
# buck
# aide
# martians
# kennedy
# secluded
# unwittingly
# seduce
# dressed
# sexpot
# lisa
# marie
# ed
# wood
# earlier
# studied
# sexuality
# pages
# sarah
# jessica
# parker
# hosts
# newsman
# sylvia
# sidney
# cackles
# blew
# congress
# decisive
# defeat
# jones
# vegasbased
# barbet
# schroeder
# reversal
# fortune
# cameo
# unfortunate
# french
# underutilized
# annette
# bening
# pierce
# brosnan
# lukas
# haas
# latter
# allens
# computergenerated
# fantastic
# bare
# glistening
# grinning
# round
# pupils
# darting
# invaders
# incarnate
# dantes
# closest
# equivalent
# inventive
# raison
# detre
# crimes
# crumble
# assault
# easter
# bowling
# buggers
# sheer
# staggering
# iridescent
# urged
# earned
# vary
# cheesy
# mass
# destruction
# peter
# wynn
# wildly
# define
# spike
# regimen
# crash
# cronenberg
# cronenbergs
# somber
# surely
# nightmare
# duped
# empty
# conveniently
# avoided
# saving
# selfabsorbed
# dependent
# partly
# surviving
# innocents
# ultimate
# susceptible
# strains
# messy
# masterpiece
# funniest
# weird
# affirmation
# reunion
# subgenres
# prep
# slasher
# peters
# remarkable
# creates
# hanging
# eachother
# crisis
# spoken
# intervals
# neurotic
# seperate
# crises
# invited
# marginally
# built
# nostalgic
# causing
# coined
# chill
# bitching
# confessionals
# broken
# tad
# whiny
# unsatisfying
# poignant
# theatre
# outrageous
# dancing
# tux
# fry
# briers
# register
# mansion
# immeadiately
# inviting
# chums
# tenth
# andrew
# kenneth
# branagh
# carol
# cowriter
# rita
# rudner
# maggie
# emma
# thompson
# publisher
# selfhelp
# customers
# laurie
# sensibility
# creators
# newly
# twins
# emmanuel
# promiscuous
# slattery
# divorce
# doubts
# anecdotes
# confessions
# brawls
# dug
# anticlimactic
# join
# clique
# someones
# mention
# grew
# classics
# tears
# everybody
# id
# crap
# gos
# eileen
# talking
# branaghs
# forte
# magical
# ambiguous
# bregman
# puns
# mock
# logs
# punishment
# outsiders
# housekeeper
# doses
# prozac
# dramatically
# pine
# maintain
# divide
# groups
# preferences
# featured
# explosions
# preferred
# hong
# kong
# martial
# imitate
# overexposure
# idiocy
# kung
# fu
# cheap
# guilty
# pleasure
# relaxation
# cult
# status
# quarter
# century
# enter
# joint
# venture
# bruce
# lees
# western
# succeeded
# debatable
# myth
# shaolin
# monk
# interpol
# official
# tournament
# owned
# han
# renegade
# gunrunning
# prostitution
# operations
# necessary
# intervene
# reasons
# oharra
# hans
# brutal
# destination
# williams
# kelly
# activist
# racist
# roper
# gambling
# debts
# faced
# powerhungry
# megalomaniac
# deprived
# guns
# internal
# avenge
# opportunities
# evaluate
# saxon
# worst
# bondian
# fist
# fodder
# chan
# lack
# associated
# demanding
# incapacitate
# opponent
# masses
# floor
# former
# retrospective
# leans
# institutes
# lumets
# angry
# wilders
# witness
# prosecution
# kubricks
# paths
# glory
# deny
# importance
# bridge
# kwai
# cinematically
# contents
# burma
# soldiers
# japanese
# captivity
# strategically
# momentous
# railway
# commanding
# alec
# guinness
# insists
# corresponding
# geneva
# officers
# neednt
# workmen
# toughly
# col
# commandant
# saito
# sessue
# hayakawa
# assiduously
# commits
# morale
# capabilities
# command
# sends
# shears
# holden
# escapee
# warden
# hawkins
# clich
# inferior
# incapable
# kubrick
# fascinated
# hierarchies
# perceptible
# symptomatic
# applaud
# nicholsons
# perseverance
# concerning
# spectators
# neglect
# bypasses
# virtues
# possessed
# cynics
# clashing
# interests
# inconsistencies
# atmospherically
# magnificent
# apt
# extraordinary
# karl
# rackwitz
# ris
# germany
# quirks
# labour
# humour
# roberto
# benigni
# ugly
# obnoxious
# amounted
# finer
# intricacies
# strips
# superficiality
# underneath
# nazis
# concentration
# convinces
# hey
# previews
# bulworth
# wonders
# allow
# beatty
# missed
# warren
# politician
# congregation
# malt
# liquor
# chicken
# wings
# stabs
# rid
# billington
# longtime
# senator
# repetitious
# bulworths
# commercials
# condemning
# ironically
# intercut
# luther
# lay
# morosely
# weeping
# front
# food
# sleep
# entering
# weekend
# depression
# sunk
# insurance
# bribe
# policy
# daughters
# associate
# arrange
# assassination
# platt
# oblivious
# suicidal
# drags
# engagements
# halfheartedly
# speech
# africanamerican
# church
# voting
# rebuild
# riots
# hasnt
# truthfully
# promises
# improved
# counted
# outrage
# distinction
# denver
# post
# characterizing
# africanamericans
# trailers
# praised
# praise
# liberating
# restricted
# generic
# platitudes
# mouth
# lobbyists
# populace
# protects
# politicians
# charges
# volunteers
# nikki
# halle
# barry
# crush
# eats
# appropriately
# late
# ratings
# drifts
# topic
# product
# callously
# admits
# jews
# drops
# nightclub
# smoking
# pot
# learning
# rap
# shuns
# raps
# suitandtie
# appearances
# middleaged
# embarrassingly
# amused
# overtakes
# cancel
# request
# closing
# distracted
# detracted
# ranting
# jeremy
# pikser
# cowrote
# convincingly
# liberation
# rebirth
# hollywoods
# indulgent
# formulas
# inexcusable
# tackle
# challenges
# insight
# write
# rants
# bastards
# notting
# hill
# weddings
# funeral
# anna
# price
# wanders
# resident
# begin
# turmoil
# grants
# disgusting
# roommate
# annas
# pesky
# exboyfriend
# baldwin
# complexity
# stubborn
# astonishingly
# straightforward
# teeshirt
# shirt
# parrot
# russian
# janitor
# misha
# shalhoub
# basement
# facility
# paulie
# mohr
# regales
# hallie
# eisenberg
# impediment
# attending
# maries
# lessons
# regular
# unfairly
# blamed
# pawn
# shop
# sold
# paulies
# succession
# owners
# gena
# rowlands
# cheech
# marin
# crowd
# apprehended
# los
# angeles
# jewelry
# cruel
# participate
# imprisoned
# personalities
# wellmeaning
# christmas
# birthday
# dalmatian
# kid
# purchased
# pup
# pound
# owns
# bites
# newborn
# please
# animatronic
# billing
# cartoons
# sassy
# strutting
# miniature
# anistons
# buddy
# hackett
# owner
# doubles
# customer
# tykes
# laughing
# hysterically
# cat
# elderly
# ivy
# lassie
# forth
# goodbye
# meandering
# popcorn
# moms
# dads
# wisecracks
# youngsters
# moral
# luck
# generated
# organization
# mib
# exist
# graphics
# exits
# concede
# denis
# rodman
# seriousness
# soft
# cuddly
# lighter
# ass
# smith
# aims
# recruit
# duty
# chosen
# protect
# scum
# galaxy
# awfully
# abounds
# tommy
# wittiness
# complemented
# proper
# clueless
# altogether
# blended
# marvelously
# development
# proposed
# observations
# smiths
# capsule
# suprisingly
# helluva
# hitmen
# alas
# string
# cracking
# funloving
# kirk
# oddly
# grosse
# blank
# advertised
# hints
# suprising
# dosage
# hyped
# stylized
# sore
# smiley
# cohorts
# wahlberg
# dopey
# milquetoast
# flips
# whilst
# popping
# caps
# twenty
# mode
# lasting
# electrifying
# hamper
# unenjoyable
# ramseys
# include
# oriental
# maker
# mels
# pals
# handled
# stylishly
# gutwrenchingly
# joyride
# definately
# lynchs
# highway
# remarked
# fellow
# moviegoer
# nose
# ears
# lynch
# eraserhead
# weirdness
# reasonable
# depends
# interpret
# jazz
# madison
# pullman
# patricia
# infidelity
# receive
# videotapes
# asleep
# frightened
# confused
# blake
# approaches
# proceeds
# telephone
# unnerving
# videotape
# murdering
# convicted
# inexplicably
# mechanic
# pete
# dayton
# balthazar
# getty
# perplexed
# intersect
# notably
# alice
# blonde
# spitting
# suffice
# neat
# wrap
# lid
# metaphysical
# demons
# description
# giddy
# exercise
# haywire
# surrealism
# traces
# contrary
# perplexing
# excursions
# intrigue
# farther
# revolve
# investigating
# recurring
# deeply
# images
# suspicion
# distrust
# indicate
# deluded
# fractured
# psyche
# root
# goingson
# puzzle
# driving
# freds
# meant
# typically
# slowpaced
# idiosyncratic
# imagery
# lingers
# uncomfortably
# hallway
# pained
# haunting
# mortal
# siren
# vivid
# presentations
# insanity
# demings
# suffocating
# admit
# tieins
# stock
# pornstar
# wannabes
# fortunately
# reappearance
# strained
# awkward
# preserve
# spooky
# stretch
# portrayals
# fringe
# relevant
# jealousy
# overdone
# exploitative
# frankly
# seventh
# eighth
# clothes
# attaining
# unsettling
# screens
# oneway
# disturbed
# brilliantly
# ambivalent
# mill
# victorian
# liberty
# liberal
# democracy
# wrought
# archetypal
# paradox
# supreme
# contradiction
# majority
# larger
# collective
# oppressive
# braveheart
# fourth
# july
# jfk
# singapore
# barred
# access
# penthouse
# worried
# advocating
# rights
# opposition
# locates
# within
# taboo
# pornography
# circulate
# hustler
# month
# threw
# curb
# undecided
# shunned
# embarrassing
# reprises
# antichrist
# nihilistic
# atheist
# dearly
# abandon
# sensitivity
# courtney
# snubbed
# edward
# norton
# jerky
# lawyer
# superficially
# immoral
# outcasts
# whove
# paralysed
# aids
# damnation
# standing
# nihilist
# moralist
# consequences
# atheism
# ridding
# influences
# optimism
# blah
# admire
# dares
# doctrines
# catchphrases
# reflect
# accurate
# twentyone
# trivial
# contestants
# isolation
# category
# reached
# producers
# fix
# contestant
# illustrates
# stories
# herbie
# stempel
# charles
# van
# doren
# turturro
# jewish
# reigning
# champion
# accumulated
# dan
# enright
# paymer
# queens
# welleducated
# professor
# widely
# tic
# dough
# hank
# azaria
# keen
# purpose
# throne
# cheated
# dick
# morrow
# harvard
# graduate
# wrongdoings
# yields
# trial
# redfords
# jon
# favreau
# swingers
# costar
# mugs
# career
# trajectory
# bobby
# ricky
# construction
# wannabe
# contenders
# bout
# pitted
# draw
# bobbys
# falk
# midlevel
# mobster
# rickys
# delivery
# silky
# combs
# pleads
# pal
# tag
# motormouth
# inserts
# everytime
# screws
# swaggering
# throwing
# soprano
# styles
# modernday
# hardy
# wiser
# phonograph
# needle
# yakking
# havoc
# partner
# affection
# loyalty
# binds
# shoe
# courtesy
# drop
# faux
# stumbling
# lowkey
# gangsta
# famke
# janssen
# lowlife
# loud
# talkative
# key
# watched
# improve
# confession
# adore
# unwavering
# near
# foolish
# passion
# steven
# baldwins
# seagal
# resounding
# clarify
# smug
# vogue
# gulp
# tucker
# partial
# gritty
# earthy
# dramas
# serpico
# donnie
# brasco
# connection
# bush
# multiplexes
# eager
# puppy
# bowed
# tripping
# squiggly
# tail
# transform
# moron
# wiseguy
# spinoff
# barren
# graffiti
# strewn
# criminals
# lurk
# knights
# shield
# clutches
# guessing
# precisely
# feelings
# tots
# gi
# joes
# enact
# robbers
# cowboy
# fantasies
# tap
# gleeful
# heighten
# existential
# tastes
# drastically
# complexities
# krzysztof
# kieslowski
# potentially
# whore
# corrupt
# ooh
# protectors
# service
# advantage
# gain
# courtroom
# tremendously
# absorbing
# lumet
# prince
# undercover
# loath
# kristy
# michelle
# gellar
# utterly
# skyrocketed
# brad
# pitt
# hatched
# mere
# judging
# tripe
# heat
# mickey
# rourke
# eric
# purgatory
# keanu
# reeves
# dissimilar
# pacinos
# elite
# squad
# dealers
# uniforms
# vigilantes
# analogy
# sorta
# junkies
# info
# junk
# fairly
# honorable
# intentions
# seeks
# redemption
# concludes
# affairs
# convince
# rat
# partners
# moved
# betrayal
# ambiguity
# oneself
# risky
# perceptive
# boiled
# ...
# raccoon
# alessa
# bosom
# uninterested
# triggering
# remnants
# endemic
# amuck
# riddler
# splat
# rhino
# arguable
# annoyingly
# junky
# wendt
# wonderbra
# snails
# indecipherable
# demolition
# emilio
# estevez
# teamwork
# whit
# dolittle
# klumps
# sherman
# klump
# beaker
# flabby
# wipes
# bins
# overworked
# eraser
# tunney
# jericho
# overpriced
# gabriels
# manns
# manhunter
# eventempered
# temptations
# cuesta
# pakula
# howies
# illadvised
# whitey
# hc
# jb
# perennial
# wh
# prospect
# exhibition
# huffs
# hitter
# conceited
# absences
# strikeout
# durham
# bilko
# stripes
# meatballs
# larroquette
# stove
# blaze
# jeans
# investor
# feldmans
# mush
# hatchers
# champions
# wavering
# rosemarys
# skewered
# alls
# potions
# fichtners
# dwayne
# oneandahalf
# inperson
# lacey
# sloppily
# slappedtogether
# goldsman
# cohesion
# spaced
# maureen
# sabotaged
# blawp
# lindsey
# prophecies
# kickoff
# vci
# turners
# boggs
# dawkins
# nitro
# palitaliano
# bischoff
# rehired
# wcws
# wrestlers
# mcmahons
# mcmahon
# rockystyle
# sasha
# pseudodocumentary
# unconvincingly
# cowering
# skeptic
# nauseated
# jeffreys
# miscarriage
# suggestions
# perpetrated
# bokeem
# woodbine
# keifer
# outworld
# shao
# sorcerer
# rayden
# shou
# sindel
# magma
# tunnels
# hess
# jax
# oahu
# researchers
# flipped
# expletive
# ratcliffe
# traveler
# valiantly
# claptrap
# swill
# deteriorates
# rodent
# forties
# macnee
# wynter
# englands
# wasps
# chechik
# diabolique
# ashe
# hyams
# puffing
# filmand
# mcconaughay
# overemotional
# kindergarten
# burglar
# alltoobrief
# porters
# imperative
# differentiated
# loop
# crackle
# melodramas
# graynamore
# mineral
# graynamores
# tong
# bulldog
# rewatch
# suceeds
# voted
# thanking
# heyst
# heysts
# rumoured
# lacklustre
# subtext
# almas
# schomberg
# endowed
# cockney
# volcanoes
# munchkin
# digimon
# keeble
# dubya
# pinpoint
# hottest
# doofus
# robed
# puking
# lil
# araki
# foreplay
# coitus
# har
# angsty
# macgowan
# duval
# licks
# dispondent
# bitchy
# strobe
# searched
# burglary
# bernhard
# cbs
# mistreatment
# fumble
# uncharacteristically
# savagely
# medfield
# absentmindedness
# marsden
# assimilating
# cafeteria
# laptops
# nutter
# sadler
# potheads
# commissioner
# arquettes
# potty
# farts
# wasteful
# wwf
# hotter
# hourlong
# fishes
# plodding
# voyeur
# precariously
# terrys
# wristwatch
# capitalise
# mournful
# bythenumbers
# realising
# tricking
# stammering
# shuttle
# klutzy
# overbeck
# offspring
# fastfood
# massproduced
# oise
# thirds
# leos
# transit
# emile
# dann
# emmannuelle
# leyland
# surplus
# cringeworthy
# sneeze
# chaired
# selfprofessed
# leaden
# carelessly
# rehashes
# turtletaub
# theo
# caulder
# caulders
# pego
# mangle
# clicheridden
# cuckoos
# dodging
# halfbrother
# cod
# abs
# townie
# tenley
# biel
# brittany
# leprechaun
# ungodly
# prinzes
# liable
# laughometer
# buckwheat
# discredit
# beginnings
# nonchalant
# enquirer
# barbecue
# ohlmyer
# goddard
# consoles
# mcconnell
# delaney
# rover
# scan
# meteorite
# crusoe
# offence
# kitano
# yakuza
# dishonor
# assasinate
# romps
# hemisphere
# declan
# sprays
# proposterous
# greer
# benz
# erickson
# berkshire
# fern
# mayo
# shayne
# marcie
# purr
# roldan
# stuffs
# courtneys
# vylette
# popsicle
# vickie
# hoo
# bilkos
# unfunniest
# imcomprehinsable
# merges
# birthed
# pigeon
# evince
# insinuate
# bettys
# jells
# typhoon
# robotics
# pumpedup
# dolphin
# mona
# schumaccer
# glitzy
# goldsmiths
# elle
# booty
# reconsider
# waldo
# motherdaughter
# yawner
# unruly
# dreamer
# gia
# bores
# horta
# ideaa
# mustve
# kinnears
# reputable
# grime
# flaunting
# suckers
# editted
# scummy
# dowling
# jacksonville
# racoon
# windy
# darcy
# tis
# ohsocleverly
# anyways
# sheesh
# spooked
# jeez
# exploitive
# alerted
# tomaso
# satans
# highbudget
# confining
# jello
# pizzazz
# mannequins
# ding
# lachman
# sextons
# spicers
# listing
# goop
# sweeney
# flaus
# wendys
# elmaloglou
# zaniness
# withering
# jojo
# melbourne
# flickering
# smelly
# deadbang
# becks
# shopkeeper
# manchurian
# atrociously
# bythebook
# interrogates
# sadie
# colton
# maughams
# czechoslovakia
# tgif
# puppetry
# meier
# directorscreenwriter
# mare
# missus
# hots
# kinks
# hijinx
# beal
# delany
# reifsnyder
# joshuas
# mustache
# loeb
# kattans
# zaillian
# schlictmann
# drugaddict
# tediously
# unmoved
# fooling
# sleepwalks
# unbilled
# mushrooms
# ingesting
# mushroom
# bender
# lizards
# groucho
# sputters
# akroyd
# overdirecting
# bs
# torches
# whould
# baywatch
# softcore
# fullyclothed
# biceps
# dogooder
# greystoke
# trackers
# unashamedly
# twas
# emblazoned
# keenen
# lurches
# header
# chestnuts
# remedial
# nicotine
# muggers
# lowry
# familyfriendly
# landslide
# conduit
# paulina
# confusingly
# lugubrious
# deedles
# stew
# deedle
# yellowstone
# fiendish
# sighting
# hogget
# norse
# decapitating
# torrential
# oedekerk
# diseases
# raider
# rubble
# poorlystaged
# puffy
# tits
# cavernous
# lamest
# align
# reassembled
# laras
# ustinovs
# brewsters
# putrid
# finnegan
# argonauticus
# canton
# finnegans
# consistency
# proximity
# colonize
# contingent
# jupiter
# overdo
# prescription
# wizards
# radiationinduced
# blackwolf
# luftwaffe
# traced
# hector
# gwens
# elects
# publicist
# kiki
# garnering
# snarky
# butchers
# crabs
# flanery
# clarkson
# amandas
# unamusing
# semilikable
# prolong
# reflex
# seminaked
# fess
# kink
# prochnow
# quadrangle
# ips
# grievous
# proctor
# abigail
# smears
# summoned
# pandoras
# abigails
# inexorable
# hytner
# pedestal
# huffing
# diversions
# bewitching
# swims
# machineguns
# macpherson
# dumas
# spiritless
# dartagnan
# febre
# lackey
# richelieu
# athos
# timecop
# barcelona
# gaby
# actioncrime
# richie
# badasses
# richies
# cummings
# stillliving
# enslaved
# terl
# mananimal
# scientology
# scientologist
# cavemen
# palmers
# sherilyn
# fenn
# lauras
# griswold
# griswolds
# latters
# sharif
# menzies
# jurrasic
# bloomingdales
# inanely
# glancing
# freakin
# plod
# koster
# elisabeths
# lithium
# hannigan
# reunites
# sickeningly
# stifler
# cheapened
# betraying
# rodgers
# shielded
# inimitable
# sagemiller
# annabel
# cassie
# morses
# arkins
# arisen
# whitfield
# darnells
# unhealthy
# della
# harrassing
# hypothetically
# hoenicker
# wesson
# belloq
# asswhole
# poppins
# wrightpenn
# illeana
# garret
# garrets
# vies
# cokehead
# ohso
# aaliyah
# penetrated
# deathdefying
# devitos
# pronounces
# lamebrained
# truckers
# baddie
# clairvoyant
# mumbled
# telekinesis
# endanger
# visjnic
# spat
# exorcism
# talentless
# noodleheaded
# execrable
# cheapie
# trys
# badgers
# hasten
# extemely
# whipped
# hodges
# yemen
# yemeni
# ordering
# friedklin
# depended
# backup
# moxxon
# slaughterhouse
# moxxons
# hick
# unacceptable
# lela
# rochon
# souza
# innerworkings
# memphis
# raines
# kip
# bungles
# throttle
# crest
# nitrous
# oxide
# countered
# fab
# fours
# shale
# yale
# homeboys
# kod
# excop
# joness
# felatio
# guccione
# incomprehensibly
# tiberius
# recounting
# lesbo
# robicheaux
# joanou
# scroll
# chortling
# colorado
# retail
# mysterians
# mysterty
# alaska
# roach
# dicillo
# marlo
# bridgette
# caulfield
# whines
# undeveloped
# mutilated
# playmate
# silicone
# congressional
# vandamme
# accomplices
# cora
# reef
# noseworthy
# slug
# whitlow
# hazard
# marathon
# gregor
# remade
# chabat
# abril
# marijo
# cowriterdirector
# josiane
# balasko
# frenchcanadian
# mirkine
# treill
# shootem
# infiltrates
# italians
# insomniac
# brunt
# fashions
# dauphin
# miscue
# joans
# lollies
# frightfully
# crumbs
# uhhuh
# meanness
# shelling
# krugers
# rds
# pecan
# cellmate
# ashleys
# morneau
# growling
# goliath
# longlived
# fittingly
# unforgiveable
# affluent
# flavoring
# qu
# ying
# recoup
# blinded
# confucius
# currency
# cleaver
# blob
# jammed
# smits
# ashes
# satanic
# bonehead
# partnerincrime
# dabo
# belching
# bellowing
# frosted
# tho
# mosleys
# loanshark
# stiers
# ashly
# drabby
# mananimals
# maddog
# ineffectual
# villa
# sunning
# onetwopunch
# boulder
# logan
# fetch
# deedee
# melliss
# scintos
# skindiving
# complication
# respectability
# widmark
# beards
# glazers
# reputedly
# halfworld
# tempt
# halfalien
# gamely
# mutter
# churns
# serialkiller
# hoppe
# paintbynumbers
# rapaport
# parachutes
# ignite
# hideaway
# pointlessly
# prepubescent
# gaerity
# doves
# chompers
# alf
# drivethru
# tolerant
# genieveve
# humored
# roundtree
# snore
# alltoo
# glenda
# bio
# aborted
# huntingburg
# yost
# mikael
# salomon
# asner
# sneers
# rangoon
# excalibur
# multiply
# northmen
# summons
# cannibals
# looker
# fabio
# frizzi
# mccoll
# dunwich
# fulcis
# cleavagebusting
# enthralling
# snuffing
# invisibility
# krueger
# verhoven
# peeping
# exploiting
# apex
# midweek
# grumpier
# grumpiest
# matthaus
# hackwork
# supernova
# softy
# marley
# kaela
# yerzy
# danika
# benj
# larson
# signified
# geological
# survey
# wando
# alarmed
# amorous
# labeling
# lakes
# stoddard
# hawn
# befitting
# ishtar
# overhearing
# snack
# rifle
# seldes
# quirkily
# retreads
# magoos
# consigned
# sulka
# franklins
# levying
# misrepresenting
# baileygaites
# tooforgiving
# repressed
# manifests
# jumproping
# newsmagazine
# sleightofhand
# grossness
# midgets
# albinos
# rote
# curveballs
# softtossed
# mongo
# brownlee
# jerod
# mixon
# whitebread
# toopleasant
# schitck
# patented
# contort
# splitsecond
# roleshifting
# zellwegers
# shapeless
# dissolved
# highcaliber
# advise
# silverado
# anders
# mademoiselle
# viruslike
# histories
# superintendent
# briefer
# ufoology
# greys
# writercreator
# cannibalize
# nbsp
# allimportant
# creepier
# imdb
# goof
# dade
# cereal
# degrading
# lads
# doubleteam
# desouza
# schneiders
# microbombs
# tsuis
# preposterously
# tigerland
# founding
# exasperating
# selfappointed
# fret
# purports
# kalvert
# posse
# asinine
# garb
# vic
# spanner
# beattie
# budgie
# ocallaghan
# talbot
# rothwell
# sprouse
# hooters
# prefabricated
# chisholm
# clubhopping
# environmentally
# campfire
# grimly
# kahl
# oboe
# kinfolk
# institutionalized
# krays
# shawnee
# paull
# glob
# daisies
# irishman
# twoyear
# shelmickedmu
# apologizes
# selfindulgent
# uninvolved
# evaporated
# vip
# jab
# hishertheir
# ghostfaces
# isare
# matarazzo
# christophers
# blasphemy
# squarely
# stoners
# halfasleep
# leash
# substituted
# apparantly
# hatchett
# hoodlum
# thomspon
# unfilmable
# mahurin
# knepper
# oneman
# unfailingly
# accumulation
# suppress
# lynns
# lawnmower
# quebec
# hamming
# tulip
# tudeski
# dental
# chuckled
# facetious
# projector
# igniting
# duplication
# adjacent
# rko
# patched
# bakers
# therons
# kristopherson
# taggert
# epa
# environmental
# porches
# seige
# swordfish
# jackman
# coerce
# mercer
# oblige
# prerequisite
# rash
# turgeon
# biomolecular
# fatty
# prentice
# expelled
# goon
# jackets
# foo
# sexier
# snide
# kims
# juxtaposition
# leathers
# cribbed
# monolith
# garbled
# zerogravity
# gagging
# facilitated
# jetpacks
# cruisers
# crimefighters
# dylans
# knockin
# honks
# spun
# foxx
# lila
# dubois
# diners
# yuri
# zeltser
# bradley
# sheffer
# earthworms
# imbeciles
# parted
# selfparody
# scaramangas
# funhouse
# jung
# dullest
# prances
# santanico
# quintano
# disorganised
# negotiation
# maturing
# schlocky
# fahey
# reliving
# dobie
# dobies
# sarahs
# succinctly
# granite
# modernization
# nooooo
# manipulates
# langes
# streetcar
# sustained
# multitiered
# theatergoers
# banshee
# dicillos
# wham
# tails
# splattered
# roared
# industrialist
# automaton
# golf
# certifiable
# twelveyearold
# stansfield
# wildeyed
# teases
# garofolo
# parenthood
# macht
# thaddeus
# pinkerton
# railroads
# dependable
# lebrock
# brolins
# successors
# accidently
# tut
# elwood
# calloway
# cabel
# faintest
# builtin
# vamp
# catwoman
# ginty
# perrys
# farleys
# alfreds
# coolio
# satiric
# flounders
# fiddle
# prohibitionera
# yojimbo
# hammett
# allegiance
# lawman
# lisbon
# arty
# kleenex
# romanian
# lumbers
# lehmann
# seltzer
# sideeffects
# wigand
# wigands
# severance
# jonah
# bunz
# rushon
# tamala
# lysterine
# condoms
# fluent
# kayley
# belated
# garrett
# runin
# urkel
# pinchot
# volunteer
# jose
# breakfastofchampions
# midland
# dwaynes
# trout
# avail
# squeals
# boosting
# calitri
# ticked
# hunka
# royalties
# clitoris
# unattended
# danzas
# buddying
# olmstead
# bureau
# flexible
# constipated
# fistfight
# muck
# nite
# twominute
# cara
# warfield
# maher
# jagger
# abetting
# rampaging
# shrill
# demonstrations
# toho
# burr
# niko
# phillipe
# nitpicky
# drews
# aldys
# arcs
# nadir
# jumpstart
# fiddling
# amiel
# macdougal
# headlined
# autistic
# jeffries
# miko
# infuriates
# autism
# sliminess
# complement
# coax
# violation
# ds
# tuesday
# ollie
# darrell
# scrubbed
# circling
# erotica
# cheeziness
# locally
# counselors
# overuses
# wildest
# ravens
# opar
# weismuller
# allnight
# coyotes
# moxon
# footballcrazy
# bronze
# missable
# dial
# suchet
# doppelganger
# fay
# irritate
# copulation
# onstage
# thirtysix
# infested
# exemplifies
# pottymouth
# tribunal
# kumble
# swoosie
# ablaze
# miner
# roomie
# hospitable
# dissection
# scams
# disenchanted
# cutaway
# bludgeons
# noxious
# eyed
# propellers
# waaaaay
# sec
# alexandre
# xiong
# dartagnans
# aramis
# porthos
# kremp
# rookies
# eccentrics
# preppies
# rewatched
# nebbish
# hirsch
# reestablish
# regurgitation
# dung
# werewolfism
# platinum
# brags
# smelling
# ovitz
# unprintable
# maggots
# egodriven
# declined
# thingie
# ooooh
# maelstrom
# mimics
# kitsch
# enlighten
# cavanaugh
# cavanaughs
# artificiality
# sisterhood
# telemarketer
# nursing
# expel
# filth
# attendance
# tactical
# disregards
# insultingly
# urbanlegend
# pendleton
# iknow
# loretta
# unappetizing
# infomercial
# thrax
# drix
# pulsating
# awesomely
# arcade
# mortals
# outworlds
# sheeva
# kitana
# mk
# riddles
# differentiate
# headacheinducing
# surpassed
# overtaken
# sinbad
# turboman
# deejay
# shameful
# polishwedding
# jadzia
# bolek
# hala
# miscues
# pickles
# spastic
# dullard
# juices
# baffling
# misspelling
# snazzy
# tinam
# ambience
# halfinteresting
# outgrown
# polo
# limey
# lillianna
# pools
# thorn
# jiro
# nishi
# goddaughter
# ciscos
# scumball
# cleanup
# scumballs
# organs
# meathooks
# syrup
# pillpoppin
# saluting
# sunhill
# fowler
# selecting
# dailies
# racks
# softporn
# insomniacs
# mopey
# obscenely
# munsters
# domestically
# flutters
# implanting
# gauntlet
# sinfully
# cakes
# retreating
# dietz
# dietzs
# cracker
# sw
# ammo
# adlib
# selective
# replacements
# gilligan
# berman
# briar
# minutiae
# nexus
# gravy
# bumpy
# hassidic
# thal
# gord
# sandwich
# groaninducing
# trachtenberg
# dabney
# quimby
# hughley
# rabidly
# womanabusing
# paddles
# mandrake
# boneheaded
# cassavetes
# jeanluke
# figueroa
# northam
# floppy
# broads
# discourse
# tasmania
# tourettes
# klines
# quantify
# nword
# korman
# lamarr
# trois
# jermaine
# slithers
# jasmines
# jermaines
# workplace
# phonesex
# carojeanpierre
# louison
# marielaure
# dougnac
# clapet
# karin
# viard
# holgado
# tapioca
# madame
# mathou
# kube
# vernon
# boban
# janevski
# rascal
# todde
# ortega
# silvie
# laguna
# tenement
# pipe
# bumble
# remarries
# marshalls
# residue
# illsynched
# promoters
# pummel
# orchestrating
# suitcases
# mommie
# dearest
# racked
# froth
# cadaverous
# pritchett
# plagiarized
# kiddieporn
# merteuil
# wronged
# hargrove
# intellectuals
# rugrats
# threeyearold
# dill
# doa
# geiger
# desaster
# mnemonic
# newark
# rockers
# drek
# pouting
# assuring
# smooch
# caverns
# excites
# bungalow
# ubar
# joff
# petite
# gwar
# smoother
# argonautica
# fingernails
# maureens
# groaned
# realizations
# klutz
# saxophone
# threeminute
# oneupmanship
# impostors
# binges
# panaro
# overcooked
# canoe
# wyatts
# tombstone
# eradicated
# demornay
# overlooking
# disinterest
# everton
# julio
# mechoso
# augustus
# oooh
# mook
# xing
# finals
# bluescreening
# preschoolers
# nothin
# nauseam
# goofball
# zach
# zachs
# psychotherapy
# bluth
# stephie
# hudsons
# chapelle
# cocacola
# mael
# zimmerly
# ramona
# midgett
# amblyn
# clap
# eyeball
# damato
# rut
# beaman
# leviathan
# tugboat
# matriarchal
# chows
# incidently
# moreaus
# beastpeople
# mufti
# beads
# seague
# flatter
# semester
# pronouncing
# pejorative
# cristoffer
# cristofer
# robinsons
# squeakyclean
# regressive
# cheesiest
# hoosiers
# sumo
# taplitz
# shalt
# rachels
# demarkov
# falcone
# gravesite
# miniscule
# blitz
# originator
# alligators
# leezerd
# radiated
# patillo
# bickers
# blackmailers
# catherines
# tvmovieoftheweek
# cringes
# pseudointellectual
# raiden
# sidetracks
# maliciously
# premed
# graft
# koufax
# impersonates
# glimcher
# hoop
# drawbridge
# stiffs
# leguizamos
# weakly
# wakeup
# illogic
# zoot
# pest
# turteltaub
# runnings
# cnote
# rosebudd
# lampoon
# doofy
# crybaby
# riflely
# lick
# sheltons
# fedoras
# louder
# genes
# ultimatum
# chauvinistic
# incrowd
# rationale
# henpecked
# trashiness
# indulged
# overdramatic
# spears
# snively
# perado
# shante
# osmet
# molester
# deglamed
# witless
# romano
# zgrade
# karma
# productivity
# franciss
# deuces
# drunkenly
# paradoxes
# slambang
# darryls
# tinto
# schellenberg
# wallenberg
# berger
# thulin
# margerithe
# baigelman
# freddies
# jjaks
# weld
# radha
# syd
# holliday
# credence
# lassez
# parochial
# approachable
# impregnates
# jerichos
# writerdirectors
# batologist
# crunch
# keiko
# counseling
# regrets
# ludicrously
# golddiggers
# gellars
# flannery
# cinergi
# compiled
# parillaud
# siouxsie
# insist
# parillauds
# doomsday
# coscripted
# perfekt
# punctuates
# subliminal
# photocopied
# deluge
# flintstones
# embezzlement
# wilma
# jeepers
# mgmua
# drainage
# navel
# salva
# zetajoness
# stieger
# impregnating
# almasy
# eddies
# avenger
# sewage
# att
# hav
# cherot
# plentys
# grenades
# firstrun
# miley
# arraki
# lomax
# acquittal
# ivey
# toyed
# confederation
# stormtroopers
# espositos
# yum
# pokemon
# legalized
# belushis
# cleophus
# naughton
# wald
# stooped
# individually
# proval
# puke
# tomita
# lana
# passingly
# pistones
# gangsterflick
# brascos
# johto
# unown
# entei
# weirdlooking
# copperfield
# thornesmith
# septien
# exgirlfriends
# warmnfuzzy
# phnah
# jeopardize
# transvestites
# kennel
# schl
# ndorff
# obituary
# molasses
# mornay
# graph
# terraforming
# nono
# mingliang
# downpour
# quarantined
# morritz
# girard
# stoops
# kickboxing
# spiceworld
# hesse
# hawking
# knicks
# mujibur
# sirajul
# yipes
# caitlyn
# potholes
# transvestitism
# glenglenda
# ram
# shrasta
# shroff
# protruding
# elfont
# schreibers
# heartbreakers
# catharine
# carls
# catharines
# rigeur
# anns
# coughlan
# tambor
# yugo
# monas
# marcelo
# eyro
# exorcised
# chaja
# silverware
# kalman
# simcha
# chajas
# quack
# transcended
# breillats
# breillat
# ana
# reboux
# aalyah
# goofybutloveable
# aaaaaaaaah
# dangles
# torro
# overplotted
# beyer
# overextension
# gabys
# toppled
# fakelooking
# mias
# conceptual
# collars
# cuffs
# boulle
# gullivers
# robo
# duarte
# turpin
# turpins
# fancey
# strapp
# daley
# flasher
# harriett
# controllers
# falzone
# chins
# steenburgen
# pillsbury
# whitefaced
# neverland
# spaceks
# superintelligence
# goldblums
# powders
# unplugging
# electrocution
# noraruthaol
# nntphub
# cb
# aberdeen
# strindberg
# kaisa
# nossiters
# restauranteur
# stalkers
# toolbox
# moresco
# assante
# uninsightful
# aa
# lawernce
# lawerence
# lawerences
# peaches

# %% [markdown]
# ---
# <div style="text-align: right"> <font size=5> <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a></font></div>
#
# ---

# %% [markdown]
# <a id="section3"></a>
# # <font color="#004D7F" size=6>3. Entrenar CNN con capa `Embedding`</font>

# %% [markdown]
# - El primer paso es cargar el vocabulario.
# - Lo usaremos para filtrar palabras de reseñas de películas que no nos interesen.
# - Si ha trabajado en la sección anterior, debería tener un archivo local llamado `vocab.txt` con una palabra por línea.
# - Podemos cargar ese archivo y construir un vocabulario como un conjunto para verificar la validez de lo tokens.

# %%
import string
import re
from os import listdir
from numpy import array
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.utils.vis_utils import plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# load the vocabulary
vocab_filename = 'vocab.txt'
vocab = load_doc(vocab_filename)
vocab = set(vocab.split())
# Out:
# 2022-12-05 16:47:54.703558: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-05 16:48:02.512575: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.0/include:/usr/local/cuda-11.0/lib64:
# 2022-12-05 16:48:02.513026: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.0/include:/usr/local/cuda-11.0/lib64:
# 2022-12-05 16:48:02.513061: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
vocab
# Out:
# {'awareness',
#  'hc',
#  'floom',
#  'pseudodocumentary',
#  'thanksgiving',
#  'invariably',
#  'sample',
#  'mirandas',
#  'firstrun',
#  'comedian',
#  'inn',
#  'revives',
#  'abruptly',
#  'mcalisters',
#  'remnants',
#  'modeling',
#  'wellearned',
#  'cinergi',
#  'noun',
#  'lights',
#  'firstclass',
#  'relish',
#  'dresses',
#  'incomprehensible',
#  'colorful',
#  'undiscovered',
#  'disturbs',
#  'gungho',
#  'toughtalking',
#  'assassin',
#  'tripe',
#  'udall',
#  'slomo',
#  'skintight',
#  'anne',
#  'latter',
#  'potatoes',
#  'handy',
#  'listed',
#  'unearthed',
#  'subpar',
#  'lambs',
#  'helming',
#  'cunningham',
#  'supermodel',
#  'favourites',
#  'excellently',
#  'unfolding',
#  'obtaining',
#  'overact',
#  'proponents',
#  'granted',
#  'visjnic',
#  'blues',
#  'attempts',
#  'gentle',
#  'coincides',
#  'suspenseless',
#  'stillliving',
#  'cup',
#  'inconsistent',
#  'garfield',
#  'generously',
#  'taxation',
#  'goldstein',
#  'strip',
#  'renting',
#  'mired',
#  'examinations',
#  'rabies',
#  'ranft',
#  'shipwreck',
#  'affluent',
#  'owens',
#  'keeble',
#  'portals',
#  'rables',
#  'roads',
#  'nelken',
#  'opinionated',
#  'gilligans',
#  'jaws',
#  'futileattempt',
#  'jaye',
#  'eloi',
#  'knell',
#  'slug',
#  'rockies',
#  'ruth',
#  'genx',
#  'hectic',
#  'nword',
#  'thrown',
#  'mosaffa',
#  'discredit',
#  'experimentation',
#  'fuss',
#  'cue',
#  'daugher',
#  'cain',
#  'region',
#  'pam',
#  'circuit',
#  'positions',
#  'buffs',
#  'welldone',
#  'pitted',
#  'haliwell',
#  'touch',
#  'joint',
#  'printed',
#  'spiderman',
#  'unconditional',
#  'rapaport',
#  'verisimilitude',
#  'aural',
#  'vittis',
#  'toned',
#  'onslaught',
#  'executions',
#  'rockhound',
#  'unfilmable',
#  'observance',
#  'issued',
#  'coscripted',
#  'soaking',
#  'sustenance',
#  'mac',
#  'glorias',
#  'images',
#  'exaggerated',
#  'underrated',
#  'asian',
#  'acute',
#  'morph',
#  'ye',
#  'dishonor',
#  'climbing',
#  'wordofmouth',
#  'complete',
#  'wendt',
#  'foo',
#  'laserman',
#  'entanglements',
#  'indistinguishable',
#  'gapes',
#  'isles',
#  'agnes',
#  'reels',
#  'deranged',
#  'limp',
#  'decrees',
#  'playtone',
#  'nicolet',
#  'geared',
#  'linklaters',
#  'darius',
#  'shop',
#  'mckellar',
#  'strips',
#  'cloaks',
#  'pouring',
#  'jarring',
#  'tvmovieoftheweek',
#  'criminal',
#  'clapet',
#  'fabio',
#  'elias',
#  'anymore',
#  'imf',
#  'hairdo',
#  'ruminations',
#  'crossed',
#  'prescott',
#  'cigarette',
#  'beck',
#  'scumballs',
#  'grudges',
#  'vegetable',
#  'interludes',
#  'cecilia',
#  'misplaced',
#  'seems',
#  'arresting',
#  'timetravel',
#  'askew',
#  'reticent',
#  'features',
#  'korean',
#  'vet',
#  'jaoui',
#  'lili',
#  'rather',
#  'trigger',
#  'hippie',
#  'quick',
#  'alec',
#  'donnie',
#  'fight',
#  'undulating',
#  'emmanuelle',
#  'whittled',
#  'bareknuckle',
#  'generations',
#  'times',
#  'smut',
#  'nation',
#  'twas',
#  'selfdiscovery',
#  'line',
#  'chuckie',
#  'miseries',
#  'histrionics',
#  'chajas',
#  'biologist',
#  'harrison',
#  'blows',
#  'mechoso',
#  'sheik',
#  'grier',
#  'scene',
#  'tina',
#  'orbit',
#  'unravel',
#  'klines',
#  'advertised',
#  'biederman',
#  'sheila',
#  'selfacceptance',
#  'websites',
#  'speaks',
#  'imaginary',
#  'accidental',
#  'fletcher',
#  'salesmen',
#  'paints',
#  'philadelphia',
#  'billys',
#  'lehmann',
#  'fort',
#  'cardinal',
#  'lately',
#  'emmannuelle',
#  'plenty',
#  'graininess',
#  'favorable',
#  'enjoy',
#  'homer',
#  'rejecting',
#  'wellrounded',
#  'roddy',
#  'mark',
#  'joblos',
#  'yanked',
#  'ulee',
#  'pairing',
#  'rants',
#  'exchanged',
#  'recorder',
#  'tics',
#  'proxy',
#  'asks',
#  'cameos',
#  'expressed',
#  'jamie',
#  'bmw',
#  'offensively',
#  'historically',
#  'entire',
#  'minus',
#  'toni',
#  'squeakyclean',
#  'ordering',
#  'brean',
#  'fierstein',
#  'cathrine',
#  'mickey',
#  'dante',
#  'reflecting',
#  'haunts',
#  'abominable',
#  'bittersweet',
#  'finalized',
#  'ibanez',
#  'veronica',
#  'throw',
#  'shoots',
#  'vivacious',
#  'drawnout',
#  'karin',
#  'educational',
#  'developed',
#  'quizzical',
#  'trust',
#  'distant',
#  'smell',
#  'convention',
#  'figgis',
#  'hillarous',
#  'comedically',
#  'written',
#  'brando',
#  'chicken',
#  'mystical',
#  'invading',
#  'beautiful',
#  'meditation',
#  'wessex',
#  'aspire',
#  'oasis',
#  'sunday',
#  'awakenings',
#  'carving',
#  'fancies',
#  'building',
#  'dimensional',
#  'arching',
#  'lukewarm',
#  'warmup',
#  'buckwheat',
#  'bug',
#  'manifesting',
#  'reddick',
#  'needed',
#  'sanders',
#  'limply',
#  'inserting',
#  'mushrooms',
#  'examined',
#  'brooke',
#  'carrere',
#  'zimmerly',
#  'thief',
#  'raps',
#  'recurring',
#  'yuppie',
#  'fluctuates',
#  'novak',
#  'swiftness',
#  'tatooine',
#  'lloyd',
#  'yearnings',
#  'pursuer',
#  'young',
#  'pretends',
#  'heigl',
#  'incest',
#  'slams',
#  'pullman',
#  'tale',
#  'morale',
#  'armed',
#  'returns',
#  'swooping',
#  'ghallager',
#  'yea',
#  'inquisition',
#  'golddiggers',
#  'swear',
#  'busby',
#  'ernie',
#  'romeos',
#  'putting',
#  'sexpot',
#  'wit',
#  'formulas',
#  'devises',
#  'respectable',
#  'mast',
#  'insulting',
#  'terminator',
#  'identities',
#  'winona',
#  'dullness',
#  'trachtenberg',
#  'sensibilities',
#  'shakes',
#  'leprechaun',
#  'ambiguities',
#  'unfunny',
#  'pollack',
#  'lighter',
#  'lived',
#  'trumans',
#  'drugaddicted',
#  'tullymore',
#  'adaptation',
#  'savor',
#  'munson',
#  'sugary',
#  'revealed',
#  'selfawareness',
#  'hein',
#  'resurrecting',
#  'aladdin',
#  'deterioration',
#  'marin',
#  'selfimposed',
#  'brings',
#  'strangeness',
#  'purposeful',
#  'scary',
#  'lars',
#  'corinthians',
#  'thrill',
#  'nzonzi',
#  'rejects',
#  'rewarded',
#  'osmet',
#  'bourgeoisie',
#  'dunaway',
#  'disorienting',
#  'knee',
#  'liquor',
#  'realitybased',
#  'label',
#  'dubs',
#  'uninitiated',
#  'marketable',
#  'gullivers',
#  'massironi',
#  'wash',
#  'christophers',
#  'sorted',
#  'approved',
#  'pro',
#  'council',
#  'originator',
#  'run',
#  'resurfaces',
#  'jai',
#  'ripoffs',
#  'slayings',
#  'cargo',
#  'slope',
#  'skids',
#  'oneal',
#  'italy',
#  'chosen',
#  'mistakenly',
#  'motsss',
#  'variations',
#  'dour',
#  'ingenue',
#  'shabby',
#  'tapestry',
#  'selective',
#  'butler',
#  'aweinspiring',
#  'microbombs',
#  'destined',
#  'volumes',
#  'trifle',
#  'aims',
#  'hankss',
#  'henri',
#  'concrete',
#  'seduced',
#  'bellowing',
#  'amounted',
#  'quote',
#  'urgency',
#  'copperfield',
#  'figure',
#  'distasteful',
#  'influential',
#  'goldblums',
#  'pawns',
#  'skits',
#  'controversies',
#  'reinvented',
#  'suns',
#  'finale',
#  'lundgren',
#  'static',
#  'guttenberg',
#  'lapsed',
#  'unequivocal',
#  'cassandra',
#  'frightened',
#  'matches',
#  'guilt',
#  'duty',
#  'greystoke',
#  'lyonne',
#  'deems',
#  'bracco',
#  'vendor',
#  'missile',
#  'vito',
#  'dedicates',
#  'eriq',
#  'earliest',
#  'coolness',
#  'married',
#  'christened',
#  'befriends',
#  'disputes',
#  'sinuous',
#  'stallones',
#  'truckload',
#  'stainedglass',
#  'moves',
#  'mcginley',
#  'chart',
#  'dense',
#  'buildings',
#  'junkie',
#  'deepened',
#  'stumbles',
#  'doorway',
#  'inaccurately',
#  'dolphin',
#  'natasha',
#  'rewrites',
#  'underling',
#  'cyrus',
#  'shapeless',
#  'cinderella',
#  'busboy',
#  'crock',
#  'koontz',
#  'rosy',
#  'disgusted',
#  'pouts',
#  'shaking',
#  'suitably',
#  'cashier',
#  'charlotte',
#  'nbcs',
#  'zany',
#  'forgiveness',
#  'innovation',
#  'idolizes',
#  'battered',
#  'nosy',
#  'hairdresser',
#  'jenette',
#  'deceptively',
#  'fated',
#  'help',
#  'recites',
#  'bash',
#  'italians',
#  'mook',
#  'seatbelts',
#  'transylvanians',
#  'recap',
#  'hairstyles',
#  'horrifying',
#  'overuse',
#  'retarded',
#  'daniel',
#  'bestselling',
#  'ranch',
#  'ropes',
#  'inhibit',
#  'henchmen',
#  'wrapping',
#  'greener',
#  'helpful',
#  'heights',
#  'tasmania',
#  'womanabusing',
#  'loyalties',
#  'subsequently',
#  'frustration',
#  'widely',
#  'chemical',
#  'patrics',
#  'caper',
#  'geek',
#  'shoddy',
#  'ammunition',
#  'olympic',
#  'dubbed',
#  'uhf',
#  'butterworth',
#  'mercy',
#  'cinematographers',
#  'interoffice',
#  'spoofs',
#  'earthshattering',
#  'oooh',
#  'realise',
#  'highoctane',
#  'holes',
#  'centres',
#  'dimension',
#  'always',
#  'honing',
#  'turkeys',
#  'disillusionment',
#  'unduly',
#  'spelled',
#  'swain',
#  'escort',
#  'invaluable',
#  'jansen',
#  'flash',
#  'blindsided',
#  'honorable',
#  'thoughts',
#  'pillpoppin',
#  'cheeziness',
#  'contradictions',
#  'justifiable',
#  'yikes',
#  'sacred',
#  'juncture',
#  'butch',
#  'bros',
#  'goldfinger',
#  'halfinteresting',
#  'spike',
#  'winnfield',
#  'improved',
#  'motives',
#  'headphones',
#  'atlantic',
#  'chubby',
#  'fell',
#  'spouts',
#  'conspirator',
#  'sire',
#  'churches',
#  'perplexed',
#  'definitely',
#  'mandingos',
#  'degenerates',
#  'figured',
#  'darth',
#  'grades',
#  'grieving',
#  'pairings',
#  'organizer',
#  'safer',
#  'roelfs',
#  'achieve',
#  'cometdisaster',
#  'rhythmic',
#  'maintenance',
#  'decapitated',
#  'showtime',
#  'certificate',
#  'definitly',
#  'mil',
#  'seige',
#  'upsidedown',
#  'zuehlke',
#  'pitillo',
#  'cappie',
#  'dorn',
#  'rescued',
#  'scantily',
#  'clothing',
#  'shagadellic',
#  'smith',
#  'imperative',
#  'restore',
#  'greenwood',
#  'ribald',
#  'stifled',
#  'rebuild',
#  'speeches',
#  'blanchett',
#  'eds',
#  'casualties',
#  'pritchett',
#  'incompetence',
#  'stinks',
#  'diplomats',
#  'mine',
#  'liked',
#  'lapaglias',
#  'understandable',
#  'sacrifices',
#  'comeuppance',
#  'revels',
#  'pining',
#  'novelist',
#  'shakespeares',
#  'fashioned',
#  'virtuoso',
#  'noteworthy',
#  'underdeveloped',
#  'accompaniment',
#  'blackandwhite',
#  'terrorist',
#  'lionel',
#  'informants',
#  'mastery',
#  'filmy',
#  'gave',
#  'dave',
#  'delia',
#  'giovanni',
#  'dumber',
#  'routinely',
#  'rope',
#  'islamic',
#  'wilkinson',
#  'plea',
#  'dna',
#  'guaranteeing',
#  'likened',
#  'renard',
#  'harebrained',
#  'thunderous',
#  'captain',
#  'radiant',
#  'thinnest',
#  'overpaid',
#  'dorky',
#  'coulda',
#  'humphries',
#  'monarch',
#  'operandi',
#  'stateside',
#  'incidentally',
#  'righthand',
#  'kickass',
#  'affectionate',
#  'end',
#  'justification',
#  'starts',
#  'checks',
#  'yup',
#  'feihong',
#  'lollipop',
#  'gathering',
#  'police',
#  'educated',
#  'poisoning',
#  'socialite',
#  'naturalistic',
#  'generalized',
#  'stavros',
#  'redundant',
#  'merman',
#  'lib',
#  'melodramatic',
#  'mangled',
#  'omniscient',
#  'sixteenth',
#  'aimlessly',
#  'anthony',
#  'race',
#  'industrial',
#  'merton',
#  'efficiently',
#  'entertain',
#  'taxes',
#  'morris',
#  'advisable',
#  'intermittently',
#  'ridgemont',
#  'affect',
#  'haired',
#  'smoothly',
#  'splattering',
#  'tambor',
#  'row',
#  'neonazi',
#  'scientology',
#  'knocking',
#  'reenters',
#  'harshest',
#  'val',
#  'morocco',
#  'turbulent',
#  'horrorcomedy',
#  'mightve',
#  'heel',
#  'xavier',
#  'sh',
#  'allies',
#  'detonate',
#  'senseless',
#  'detestable',
#  'underlining',
#  'francesca',
#  'abbe',
#  'everyman',
#  'violent',
#  'stages',
#  'overjoyed',
#  'pecker',
#  'nefarious',
#  'impact',
#  'halfasleep',
#  'succumbed',
#  'stinker',
#  'nowfamous',
#  'wrongdoing',
#  'jinn',
#  'wellconstructed',
#  'hitchhike',
#  'conceived',
#  'science',
#  'annies',
#  'flex',
#  'characterdefining',
#  'away',
#  'rourke',
#  'sherilyn',
#  'volume',
#  'mk',
#  'fighter',
#  'sci',
#  'italian',
#  'jermaines',
#  'newbie',
#  'plans',
#  'enormously',
#  'pleasantville',
#  'muscles',
#  'careers',
#  'overshadowed',
#  'enlivens',
#  'unit',
#  'pockets',
#  'reef',
#  'commanded',
#  'colleges',
#  'detail',
#  'abomb',
#  'rejoice',
#  'door',
#  'philandering',
#  'underutilized',
#  'criteria',
#  'troubled',
#  'deans',
#  'photogenic',
#  'judiths',
#  'breech',
#  'yost',
#  'seniors',
#  'mant',
#  'fellini',
#  'caretaker',
#  'miss',
#  'selfinvolved',
#  'awestruck',
#  'guilty',
#  'splitscreen',
#  'merciless',
#  'substantially',
#  'respond',
#  'bland',
#  'datas',
#  'mickeys',
#  'beings',
#  'walks',
#  'sustaining',
#  'hewitts',
#  'flurry',
#  'catered',
#  'moviereviews',
#  'ego',
#  'exploits',
#  'listen',
#  'horse',
#  'tanks',
#  'scarlett',
#  'juggles',
#  'rolling',
#  'emails',
#  'kilmer',
#  'frogs',
#  'knocks',
#  'shy',
#  'mercedes',
#  'relieved',
#  'snipes',
#  'rudolph',
#  'excites',
#  'block',
#  'timid',
#  'littleknown',
#  'banishes',
#  'flashes',
#  'undecided',
#  'belgian',
#  'collaborated',
#  'aykroyd',
#  'dismisses',
#  'developing',
#  'exorcism',
#  'shells',
#  'gees',
#  'overrun',
#  'trees',
#  'violations',
#  'manipulative',
#  'kennedy',
#  'tomas',
#  'amorous',
#  'patience',
#  'partake',
#  'grocery',
#  'imam',
#  'molded',
#  'surf',
#  'hasten',
#  'introduced',
#  'welcome',
#  'kirsten',
#  'flabbergasted',
#  'strength',
#  'trouble',
#  'irvings',
#  'nauseating',
#  'revitalizing',
#  'macneill',
#  'prewar',
#  'pruitt',
#  'hurting',
#  'biggest',
#  'fanatical',
#  'sake',
#  'churned',
#  'recover',
#  'palance',
#  'spears',
#  'topnotch',
#  'inventors',
#  'sexcrazed',
#  'codgers',
#  'lovesick',
#  'principal',
#  'bury',
#  'prospect',
#  'project',
#  'outset',
#  'musketeers',
#  'disillusioned',
#  'agony',
#  'commodities',
#  'anyones',
#  'beater',
#  'cribbing',
#  'epitomizes',
#  'vultures',
#  'detailed',
#  'buren',
#  'testing',
#  'evolving',
#  'boulevard',
#  'terrors',
#  'associated',
#  'michelles',
#  'jumpy',
#  'gladiator',
#  'emmet',
#  'slow',
#  'consequence',
#  'loutish',
#  'ballistic',
#  'pie',
#  'ambiance',
#  'twist',
#  'wary',
#  'possibility',
#  'avoid',
#  'glorify',
#  'realistically',
#  'passions',
#  'finns',
#  'laughoutloud',
#  'herzfeld',
#  'sachs',
#  'yim',
#  'shark',
#  'thorne',
#  'cures',
#  'ottman',
#  'arsenal',
#  'felatio',
#  'constant',
#  'sooooo',
#  'egos',
#  'enjoyably',
#  'halfdigested',
#  'symbol',
#  'cassidy',
#  'bursts',
#  'alienating',
#  'wyatt',
#  'loretta',
#  'colonys',
#  'indication',
#  'courses',
#  'commissioned',
#  'vassili',
#  'wellplaced',
#  'valentine',
#  'transformed',
#  'thrax',
#  ...}

# %% [markdown]
# Limpiamos el documento implica dividir cada revisión en función de los espacios en blanco, eliminar la puntuación y luego filtrar todos los tokens que no están en el vocabulario.

# %%
# turn a doc into clean tokens
def clean_doc(doc, vocab):
	# split into tokens by white space
	tokens = doc.split()
	# prepare regex for char filtering
	re_punc = re.compile('[%s]' % re.escape(string.punctuation))
	# remove punctuation from each word
	tokens = [re_punc.sub('', w) for w in tokens]
	# filter out tokens not in vocab
	tokens = [w for w in tokens if w in vocab]
	tokens = ' '.join(tokens)
	return tokens

# %% [markdown]
# A continuación, debemos cargar todas las reseñas de películas de datos de entrenamiento.
#
# Creamos la función `process_docs()` para cargar los documentos, limpiarlos y devolverlos como una lista de cadenas, con un documento por cadena. Queremos que cada documento sea una cadena para facilitar la codificación como una secuencia de enteros más adelante.
#
# Actualizamos `process_docs()` para que pueda llamar a la función `clean_doc()` para cada documento en un directorio determinado.

# %%
# load all docs in a directory
def process_docs(directory, vocab, is_train):
	documents = list()
	# walk through all files in the folder
	for filename in listdir(directory):
		# skip any reviews in the test set
		if is_train and filename.startswith('cv9'):
			continue
		if not is_train and not filename.startswith('cv9'):
			continue
		# create the full path of the file to open
		path = directory + '/' + filename
		# load the doc
		doc = load_doc(path)
		# clean doc
		tokens = clean_doc(doc, vocab)
		# add to list
		documents.append(tokens)
	return documents

# %% [markdown]
# Podemos llamar a la función `process_docs()` para los directorios `neg` y `pos` y combinar las revisiones en un solo train o test. También podemos definir las etiquetas de clase para el conjunto de datos.
#
# La función `load_clean_dataset()` a continuación cargará todas las revisiones y preparará etiquetas de clase para el conjunto de datos de train/test.

# %%
# load and clean a dataset
def load_clean_dataset(vocab, is_train):
	# load documents
	neg = process_docs('data/txt_sentoken/neg', vocab, is_train)
	pos = process_docs('data/txt_sentoken/pos', vocab, is_train)
	docs = neg + pos
	# prepare labels
	labels = array([0 for _ in range(len(neg))] + [1 for _ in range(len(pos))])
	return docs, labels

# %% [markdown]
# El siguiente paso es codificar cada documento como una secuencia de números enteros.
# - La capa `Embedding` de Keras requiere entradas de enteros donde cada entero se asigna a un solo token que tiene una representación vectorial de valor real específica dentro de la incrustación.
# - Estos vectores son aleatorios al comienzo del entrenamiento, pero durante el entrenamiento se vuelven significativos para la red.
# - Podemos codificar los documentos de entrenamiento como secuencias de números enteros utilizando la clase `Tokenizer` en la API de Keras.
#     - Primero, debemos construir una instancia de la clase y luego entrenarla en todos los documentos del conjunto de datos de entrenamiento.
#     - En este caso, desarrolla un vocabulario de todos los tokens en el conjunto de datos de entrenamiento y desarrolla un mapeo consistente de palabras en el vocabulario a enteros únicos.
#     - La función `create_tokenizer()` a continuación preparará un `Tokenizer` a partir de los datos de entrenamiento.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <i class="fa fa-info-circle" aria-hidden="true"></i>
# Más información sobre la clase [`Tokenizer`](https://faroit.com/keras-docs/2.0.5/preprocessing/text/#tokenizer)

# %%
# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# %% [markdown]
# Ahora que se ha preparado la asignación de palabras a números enteros, podemos usarla para codificar las reseñas en el conjunto de datos de entrenamiento. Podemos hacer eso llamando a la función `texts_to_sequences()` en el `Tokenizer`. También debemos asegurarnos de que todos los documentos tengan la misma longitud. Este es un requisito de Keras para un cálculo eficiente. Podríamos truncar las reseñas al tamaño más pequeño o reseñas de cero (`pad` con el valor 0) a la longitud máxima, o algún híbrido. En este caso, rellenaremos todas las revisiones con la duración de la revisión más larga en el conjunto de datos de entrenamiento.
# - Primero, podemos encontrar la revisión más larga usando la función `max()` en el conjunto de datos de entrenamiento y tomar su longitud.
# - A continuación, podemos llamar a la función `pad_Sequences()` de Keras para rellenar las secuencias hasta la longitud máxima añadiendo 0 valores al final.

# %%
# load training data
train_docs, ytrain = load_clean_dataset(vocab, True)
# calculate the maximum sequence length
max_length = max([len(s.split()) for s in train_docs])
print('Maximum length: %d' % max_length)
# Out:
# Maximum length: 1317

# %% [markdown]
# Luego podemos usar la longitud máxima como un parámetro para una función para codificar enteros y rellenar las secuencias.

# %%
# integer encode and pad documents
def encode_docs(tokenizer, max_length, docs):
	# integer encode
	encoded = tokenizer.texts_to_sequences(docs)
	# pad sequences
	padded = pad_sequences(encoded, maxlen=max_length, padding='post')
	return padded

# %% [markdown]
# Ahora estamos listos para definir nuestro modelo de red neuronal.
# 1. El modelo utilizará una capa `Embedding` como la primera capa oculta.
# 2. La capa `Embedding` requiere la especificación del tamaño del vocabulario, el tamaño del espacio vectorial de valor real y la longitud máxima de los documentos de entrada.
# 3. El tamaño del vocabulario es el número total de palabras en nuestro vocabulario, más una para las palabras desconocidas.
# 4. Esta podría ser la longitud del conjunto de vocabulario o el tamaño del vocabulario dentro del `Tokenizer` utilizado para codificar los documentos con números enteros, por ejemplo:

# %%
# load training data
train_docs, ytrain = load_clean_dataset(vocab, True)
# create the tokenizer
tokenizer = create_tokenizer(train_docs)
# define vocabulary size
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary size: %d' % vocab_size)
# Out:
# Vocabulary size: 25768

# %% [markdown]
# 1. Usaremos un espacio vectorial de 100 dimensiones, pero puede probar otros valores, como 50 o 150.
# 2. La longitud máxima del documento se calculó anteriormente en la variable de longitud máxima utilizada durante el relleno.
# 3. La definición completa del modelo se enumera a continuación, incluida la capa `Embedding`.
# 4. Utilizamos una red neuronal convolucional (CNN) ya que han demostrado ser exitosos en los problemas de clasificación de documentos.
# 5. Se utiliza una configuración CNN con 32 filtros (campos paralelos para procesar palabras) y un tamaño de kernel de 8 con una función de activación `relu`.
# 6. A esto le sigue una capa de agrupación que reduce a la mitad la salida de la capa convolucional.
# 7. A continuación, la salida 2D de la parte CNN del modelo se aplana en un vector 2D largo para representar las características extraídas por CNN.
# 8. El back-end del modelo es un perceptrón multicapa estándar para interpretar las características de CNN.
# 9. La capa de salida utiliza una función de activación `sigmoid` para generar un valor entre 0 y 1 para el negativo y positivo en la reseña.

# %%
# define the model
def define_model(vocab_size, max_length):
	model = Sequential()
	model.add(Embedding(vocab_size, 100, input_length=max_length))
	model.add(Conv1D(32, 8, activation='relu'))
	model.add(MaxPooling1D())
	model.add(Flatten())
	model.add(Dense(10, activation='relu'))
	model.add(Dense(1, activation='sigmoid'))
	# compile network
	model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
	# summarize defined model
	model.summary()
	plot_model(model, to_file='model.png', show_shapes=True)
	return model

# %% [markdown]
# Podemos ver que la capa `Embedding` espera documentos con una longitud de 1317 palabras como entrada y codifica cada palabra del documento como un vector de 100 elementos y el tamaño del vocabulario de 25768.

# %%
model = define_model(vocab_size, max_length)
# Out:
# 2022-12-05 16:48:19.793111: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-05 16:48:20.404286: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-05 16:48:20.405438: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-05 16:48:20.724203: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-05 16:48:20.726983: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-05 16:48:20.728194: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-05 16:48:20.729439: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-05 16:48:26.046000: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-05 16:48:26.047491: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-05 16:48:26.048345: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-05 16:48:26.049428: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 39 MB memory:  -> device: 0, name: Quadro M1200, pci bus id: 0000:01:00.0, compute capability: 5.0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 1317, 100)         2576800
#
#  conv1d (Conv1D)             (None, 1310, 32)          25632
#
#  max_pooling1d (MaxPooling1D  (None, 655, 32)          0
#  )
#
#  flatten (Flatten)           (None, 20960)             0
#
#  dense (Dense)               (None, 10)                209610
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 2,812,053
# Trainable params: 2,812,053
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# A continuación, se guarda un gráfico del modelo definido en un archivo con el nombre `model.png`.
#   <img src="data/model_52.png" width="200" height="200" alt="CNN NLP">
#
# A continuación, ajustamos la red a los datos de entrenamiento.

# %%
# encode data
Xtrain = encode_docs(tokenizer, max_length, train_docs)
# define model
model = define_model(vocab_size, max_length)
# fit network
model.fit(Xtrain, ytrain, epochs=10, verbose=2)

# %% [markdown]
# Una vez ajustado el modelo, se guarda en un archivo denominado `model.h5` para su posterior evaluación.

# %%
# save the model
model.save('model.h5')

# %% [markdown]
# Ejecutar el ejemplo primero proporcionará un resumen del vocabulario del conjunto de datos de entrenamiento (25,768) y la longitud máxima de la secuencia de entrada en palabras (1,317). El ejemplo debería ejecutarse en unos minutos y el modelo de ajuste se guardará en un archivo.

# %% [markdown]
# ---
# <div style="text-align: right"> <font size=5> <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a></font></div>
#
# ---

# %% [markdown]
# <a id="section4"></a>
# # <font color="#004D7F" size=6>4. Evaluar modelo</font>

# %% [markdown]
# En esta sección, evaluaremos el modelo entrenado y lo usaremos para hacer predicciones sobre nuevos datos.
#
# Podemos usar la función integrada `evaluate()` para estimar la habilidad del modelo en el conjunto de datos de train y test. Esto requiere que carguemos y codifiquemos los conjuntos de datos de train y test.

# %%
# load all reviews
train_docs, ytrain = load_clean_dataset(vocab, True)
test_docs, ytest = load_clean_dataset(vocab, False)
# create the tokenizer
tokenizer = create_tokenizer(train_docs)
# define vocabulary size
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary size: %d' % vocab_size)
# calculate the maximum sequence length
max_length = max([len(s.split()) for s in train_docs])
print('Maximum length: %d' % max_length)
# encode data
Xtrain = encode_docs(tokenizer, max_length, train_docs)
Xtest = encode_docs(tokenizer, max_length, test_docs)

# %% [markdown]
# Luego podemos cargar el modelo y evaluarlo en ambos conjuntos de datos e imprimir el accuracy.

# %%
from keras.models import load_model
# load the model
model = load_model('model.h5')
# evaluate model on training dataset
_, acc = model.evaluate(Xtrain, ytrain, verbose=0)
print('Train Accuracy: %.2f' % (acc*100))
# evaluate model on test dataset
_, acc = model.evaluate(Xtest, ytest, verbose=0)
print('Test Accuracy: %.2f' % (acc*100))

# %% [markdown]
# Luego, se deben preparar nuevos datos usando la misma codificación de texto y esquemas de codificación que se usaron en el conjunto de datos de entrenamiento.
#
# Una vez preparado, se puede hacer una predicción llamando a la función `predict()` en el modelo. La siguiente función llamada `predict_sentiment()` codificará y rellenará un texto de reseña de película dado y devolverá una predicción en términos de porcentaje y una etiqueta.

# %%
# classify a review as negative or positive
def predict_sentiment(review, vocab, tokenizer, max_length, model):
	# clean review
	line = clean_doc(review, vocab)
	# encode and pad review
	padded = encode_docs(tokenizer, max_length, [line])
	# predict sentiment
	yhat = model.predict(padded, verbose=0)
	# retrieve predicted percentage and label
	percent_pos = yhat[0,0]
	if round(percent_pos) == 0:
		return (1-percent_pos), 'NEGATIVE'
	return percent_pos, 'POSITIVE'

# %% [markdown]
# Podemos probar este modelo con dos reseñas de películas ad hoc.

# %%
# test positive text
text = 'Everyone will enjoy this film. I love it, recommended!'
percent, sentiment = predict_sentiment(text, vocab, tokenizer, max_length, model)
print('Review: [%s]\nSentiment: %s (%.3f%%)' % (text, sentiment, percent*100))
# test negative text
text = 'This is a bad movie. Do not watch it. It sucks.'
percent, sentiment = predict_sentiment(text, vocab, tokenizer, max_length, model)
print('Review: [%s]\nSentiment: %s (%.3f%%)' % (text, sentiment, percent*100))

# %% [markdown]
# ---
# <div style="text-align: right"> <font size=5> <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a></font></div>
#
# ---

# %% [markdown]
# <a id="section5"></a>
# # <font color="#004D7F" size=6>5. Desarrollar un modelo CNN para n-gramas</font>

# %% [markdown]
# El modelo se puede expandir usando múltiples redes neuronales convolucionales paralelas que leen el documento fuente usando diferentes tamaños de kernel.
#
# Esto, en efecto, crea una red neuronal convolucional multicanal para texto que lee texto con diferentes **tamaños de n-gramas (grupos de palabras)**.

# %% [markdown]
# Trabajamos con las mismas funciones pero sin tener que pasarle `vocab` como argumento.

# %%
from nltk.corpus import stopwords
import string
import re

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# turn a doc into clean tokens
def clean_doc(doc):
	# split into tokens by white space
	tokens = doc.split()
	# prepare regex for char filtering
	re_punc = re.compile('[%s]' % re.escape(string.punctuation))
	# remove punctuation from each word
	tokens = [re_punc.sub('', w) for w in tokens]
	# remove remaining tokens that are not alphabetic
	tokens = [word for word in tokens if word.isalpha()]
	# filter out stop words
	stop_words = set(stopwords.words('english'))
	tokens = [w for w in tokens if not w in stop_words]
	# filter out short tokens
	tokens = [word for word in tokens if len(word) > 1]
	return tokens

# load the document
filename = 'data/txt_sentoken/pos/cv000_29590.txt'
text = load_doc(filename)
tokens = clean_doc(text)
print(tokens)
# Out:
# ['films', 'adapted', 'comic', 'books', 'plenty', 'success', 'whether', 'theyre', 'superheroes', 'batman', 'superman', 'spawn', 'geared', 'toward', 'kids', 'casper', 'arthouse', 'crowd', 'ghost', 'world', 'theres', 'never', 'really', 'comic', 'book', 'like', 'hell', 'starters', 'created', 'alan', 'moore', 'eddie', 'campbell', 'brought', 'medium', 'whole', 'new', 'level', 'mid', 'series', 'called', 'watchmen', 'say', 'moore', 'campbell', 'thoroughly', 'researched', 'subject', 'jack', 'ripper', 'would', 'like', 'saying', 'michael', 'jackson', 'starting', 'look', 'little', 'odd', 'book', 'graphic', 'novel', 'pages', 'long', 'includes', 'nearly', 'consist', 'nothing', 'footnotes', 'words', 'dont', 'dismiss', 'film', 'source', 'get', 'past', 'whole', 'comic', 'book', 'thing', 'might', 'find', 'another', 'stumbling', 'block', 'hells', 'directors', 'albert', 'allen', 'hughes', 'getting', 'hughes', 'brothers', 'direct', 'seems', 'almost', 'ludicrous', 'casting', 'carrot', 'top', 'well', 'anything', 'riddle', 'better', 'direct', 'film', 'thats', 'set', 'ghetto', 'features', 'really', 'violent', 'street', 'crime', 'mad', 'geniuses', 'behind', 'menace', 'ii', 'society', 'ghetto', 'question', 'course', 'whitechapel', 'londons', 'east', 'end', 'filthy', 'sooty', 'place', 'whores', 'called', 'unfortunates', 'starting', 'get', 'little', 'nervous', 'mysterious', 'psychopath', 'carving', 'profession', 'surgical', 'precision', 'first', 'stiff', 'turns', 'copper', 'peter', 'godley', 'robbie', 'coltrane', 'world', 'enough', 'calls', 'inspector', 'frederick', 'abberline', 'johnny', 'depp', 'blow', 'crack', 'case', 'abberline', 'widower', 'prophetic', 'dreams', 'unsuccessfully', 'tries', 'quell', 'copious', 'amounts', 'absinthe', 'opium', 'upon', 'arriving', 'whitechapel', 'befriends', 'unfortunate', 'named', 'mary', 'kelly', 'heather', 'graham', 'say', 'isnt', 'proceeds', 'investigate', 'horribly', 'gruesome', 'crimes', 'even', 'police', 'surgeon', 'cant', 'stomach', 'dont', 'think', 'anyone', 'needs', 'briefed', 'jack', 'ripper', 'wont', 'go', 'particulars', 'say', 'moore', 'campbell', 'unique', 'interesting', 'theory', 'identity', 'killer', 'reasons', 'chooses', 'slay', 'comic', 'dont', 'bother', 'cloaking', 'identity', 'ripper', 'screenwriters', 'terry', 'hayes', 'vertical', 'limit', 'rafael', 'yglesias', 'les', 'mis', 'rables', 'good', 'job', 'keeping', 'hidden', 'viewers', 'end', 'funny', 'watch', 'locals', 'blindly', 'point', 'finger', 'blame', 'jews', 'indians', 'englishman', 'could', 'never', 'capable', 'committing', 'ghastly', 'acts', 'hells', 'ending', 'whistling', 'stonecutters', 'song', 'simpsons', 'days', 'holds', 'back', 'electric', 'carwho', 'made', 'steve', 'guttenberg', 'star', 'dont', 'worry', 'itll', 'make', 'sense', 'see', 'onto', 'hells', 'appearance', 'certainly', 'dark', 'bleak', 'enough', 'surprising', 'see', 'much', 'looks', 'like', 'tim', 'burton', 'film', 'planet', 'apes', 'times', 'seems', 'like', 'sleepy', 'hollow', 'print', 'saw', 'wasnt', 'completely', 'finished', 'color', 'music', 'finalized', 'comments', 'marilyn', 'manson', 'cinematographer', 'peter', 'deming', 'dont', 'say', 'word', 'ably', 'captures', 'dreariness', 'victorianera', 'london', 'helped', 'make', 'flashy', 'killing', 'scenes', 'remind', 'crazy', 'flashbacks', 'twin', 'peaks', 'even', 'though', 'violence', 'film', 'pales', 'comparison', 'blackandwhite', 'comic', 'oscar', 'winner', 'martin', 'childs', 'shakespeare', 'love', 'production', 'design', 'turns', 'original', 'prague', 'surroundings', 'one', 'creepy', 'place', 'even', 'acting', 'hell', 'solid', 'dreamy', 'depp', 'turning', 'typically', 'strong', 'performance', 'deftly', 'handling', 'british', 'accent', 'ians', 'holm', 'joe', 'goulds', 'secret', 'richardson', 'dalmatians', 'log', 'great', 'supporting', 'roles', 'big', 'surprise', 'graham', 'cringed', 'first', 'time', 'opened', 'mouth', 'imagining', 'attempt', 'irish', 'accent', 'actually', 'wasnt', 'half', 'bad', 'film', 'however', 'good', 'stro ...

# %%
# load all docs in a directory
def process_docs(directory, is_train):
	documents = list()
	# walk through all files in the folder
	for filename in listdir(directory):
		# skip any reviews in the test set
		if is_train and filename.startswith('cv9'):
			continue
		if not is_train and not filename.startswith('cv9'):
			continue
		# create the full path of the file to open
		path = directory + '/' + filename
		# load the doc
		doc = load_doc(path)
		# clean doc
		tokens = clean_doc(doc)
		# add to list
		documents.append(tokens)
	return documents

# %%
# load and clean a dataset
def load_clean_dataset(is_train):
	# load documents
	neg = process_docs('data/txt_sentoken/neg', is_train)
	pos = process_docs('data/txt_sentoken/pos', is_train)
	docs = neg + pos
	# prepare labels
	labels = [0 for _ in range(len(neg))] + [1 for _ in range(len(pos))]
	return docs, labels

# %% [markdown]
# Guardamos los conjuntos train y test preparados en un archivo para que podamos cargarlos más tarde para el modelado y la evaluación del modelo.
#
# La función debajo llamada `save_dataset()` guardará un conjunto de datos preparado dado (elementos `X` e `y`) en un archivo usando la API `pickle` (esta es la API estándar para guardar objetos en Python).

# %%
# save a dataset to file
def save_dataset(dataset, filename):
	dump(dataset, open(filename, 'wb'))
	print('Saved: %s' % filename)

# %% [markdown]
# Ahora podemos llamar a las funciones para ejecutar nuestro ejemplo y que queden los corpus limpios.

# %%
import string
import re
from os import listdir
from nltk.corpus import stopwords
from pickle import dump

# load and clean all reviews
train_docs, ytrain = load_clean_dataset(True)
test_docs, ytest = load_clean_dataset(False)
# save training datasets
save_dataset([train_docs, ytrain], 'train.pkl')
save_dataset([test_docs, ytest], 'test.pkl')
# Out:
# Saved: train.pkl
# Saved: test.pkl

# %% [markdown]
# <a id="section51"></a>
# # <font color="#004D7F" size=5>5.1. Codificar datos</font>

# %% [markdown]
# El primer paso es cargar el conjunto de datos de entrenamiento limpio. Se puede llamar a la función denominada `load_dataset()` a continuación para cargar el conjunto de datos de entrenamiento en pickle.

# %%
# load a clean dataset
def load_dataset(filename):
	return load(open(filename, 'rb'))

# %% [markdown]
# - Debemos colocar un `Tokenizador` de Keras en el conjunto de datos de entrenamiento.
# - Usaremos este tokenizador para definir el vocabulario de la capa `Embedding` y codificar los documentos de revisión como números enteros.
# - La función `create_tokenizer()` a continuación creará un `Tokenizer` dada una lista de documentos.

# %%
# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# %% [markdown]
# También necesitamos saber la longitud máxima de las secuencias de entrada como entrada para el modelo y rellenar todas las secuencias a la longitud fija.
#
# La función `max_length()` calculará la longitud máxima (número de palabras) para todas las revisiones en el conjunto de datos de entrenamiento.

# %%
# calculate the maximum document length
def max_length(lines):
    #return max([len(s.split()) for s in lines])
    return max([len(s) for s in lines])

# %% [markdown]
# También necesitamos saber el tamaño del vocabulario para la capa `Embedding`. Esto se puede calcular a partir del `Tokenizer` preparado, de la siguiente manera:
# ```python
#     # calculate vocabulary size
#     vocab_size = len(tokenizer.word_index) + 1
# ```
#
# - Finalmente, podemos codificar enteros y rellenar el texto limpio de la reseña de la película.
# - La función de abajo `encode_text()` codificará y rellenará los datos de texto a la longitud máxima.

# %%
# encode a list of lines
def encode_text(tokenizer, lines, length):
	# integer encode
	encoded = tokenizer.texts_to_sequences(lines)
	# pad encoded sequences
	padded = pad_sequences(encoded, maxlen=length, padding='post')
	return padded

# %% [markdown]
# <a id="section52"></a>
# # <font color="#004D7F" size=5>5.2. Definir el modelo</font>

# %% [markdown]
# En Keras, se puede definir un modelo de entrada múltiple utilizando la API funcional. Definiremos un modelo con tres canales de entrada para procesar 4-gramas, 6-gramas y 8-gramas de texto. Cada canal se compone de los siguientes elementos:
# - Capa `Input` que define la longitud de las secuencias de entrada.
# - Capa `Embedding` ajustada al tamaño del vocabulario y representaciones de valor real de 100 dimensiones.
# - Capa `Conv1D` con 32 filtros y un tamaño de kernel establecido en la cantidad de palabras para leer a la vez.
# - Capa `MaxPooling1D` para consolidar la salida de la capa convolucional.
# - Capa `Flatten` para reducir la salida tridimensional a bidimensional para la concatenación.
# - La salida de los tres canales se concatena en un solo vector y se procesa mediante una capa `Dense` y una capa de salida.
#
# La siguiente función define y devuelve el modelo.

# %%
# define the model
def define_model(length, vocab_size):
	# channel 1
	inputs1 = Input(shape=(length,))
	embedding1 = Embedding(vocab_size, 100)(inputs1)
	conv1 = Conv1D(32, 4, activation='relu')(embedding1)
	drop1 = Dropout(0.5)(conv1)
	pool1 = MaxPooling1D()(drop1)
	flat1 = Flatten()(pool1)
	# channel 2
	inputs2 = Input(shape=(length,))
	embedding2 = Embedding(vocab_size, 100)(inputs2)
	conv2 = Conv1D(32, 6, activation='relu')(embedding2)
	drop2 = Dropout(0.5)(conv2)
	pool2 = MaxPooling1D()(drop2)
	flat2 = Flatten()(pool2)
	# channel 3
	inputs3 = Input(shape=(length,))
	embedding3 = Embedding(vocab_size, 100)(inputs3)
	conv3 = Conv1D(32, 8, activation='relu')(embedding3)
	drop3 = Dropout(0.5)(conv3)
	pool3 = MaxPooling1D()(drop3)
	flat3 = Flatten()(pool3)
	# merge
	merged = concatenate([flat1, flat2, flat3])
	# interpretation
	dense1 = Dense(10, activation='relu')(merged)
	outputs = Dense(1, activation='sigmoid')(dense1)
	model = Model(inputs=[inputs1, inputs2, inputs3], outputs=outputs)
	# compile
	model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
	# summarize
	model.summary()
	plot_model(model, show_shapes=True, to_file='model.png')
	return model

# %% [markdown]
# A continuación, se guarda un gráfico del modelo definido en un archivo con el nombre `model.png`.
#   <img src="data/model_53.png" width="500" height="500" alt="CNN NLP">

# %% [markdown]
# <a id="section53"></a>
# # <font color="#004D7F" size=5>5.3. Mostrar los resultados</font>

# %% [markdown]
# Ahora podemos ver el impacto de nuestra red neurnoal

# %%
from pickle import load
from numpy import array
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.utils.vis_utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers import Embedding
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers import concatenate

# load training dataset
trainLines, trainLabels = load_dataset('train.pkl')
# create tokenizer
tokenizer = create_tokenizer(trainLines)
# calculate max document length    
length = max_length(trainLines)
print('Max document length: %d' % length)
# calculate vocabulary size
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary size: %d' % vocab_size)
# encode data
trainX = encode_text(tokenizer, trainLines, length)
# define model
model = define_model(length, vocab_size)
# fit model
model.fit([trainX,trainX,trainX], array(trainLabels), epochs=7, batch_size=16)
# save the model
model.save('model.h5')
# Out:
# Max document length: 1380
# Vocabulary size: 44277
# 2022-12-05 17:03:16.602168: W tensorflow/tsl/framework/bfc_allocator.cc:479] Allocator (GPU_0_bfc) ran out of memory trying to allocate 16.89MiB (rounded to 17710848)requested by op Mul
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2022-12-05 17:03:16.602275: I tensorflow/tsl/framework/bfc_allocator.cc:1034] BFCAllocator dump for GPU_0_bfc
# 2022-12-05 17:03:16.602327: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (256): 	Total Chunks: 21, Chunks in use: 21. 5.2KiB allocated for chunks. 5.2KiB in use in bin. 304B client-requested in use in bin.
# 2022-12-05 17:03:16.602375: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-12-05 17:03:16.602417: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (1024): 	Total Chunks: 1, Chunks in use: 1. 1.2KiB allocated for chunks. 1.2KiB in use in bin. 1.0KiB client-requested in use in bin.
# 2022-12-05 17:03:16.602500: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-12-05 17:03:16.602536: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-12-05 17:03:16.602570: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-12-05 17:03:16.602602: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-12-05 17:03:16.602636: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-12-05 17:03:16.602679: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (65536): 	Total Chunks: 1, Chunks in use: 1. 100.0KiB allocated for chunks. 100.0KiB in use in bin. 100.0KiB client-requested in use in bin.
# 2022-12-05 17:03:16.602717: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (131072): 	Total Chunks: 1, Chunks in use: 0. 196.8KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-12-05 17:03:16.602751: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-12-05 17:03:16.602792: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (524288): 	Total Chunks: 1, Chunks in use: 1. 818.8KiB allocated for chunks. 818.8KiB in use in bin. 818.8KiB client-requested in use in bin.
# 2022-12-05 17:03:16.602828: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (1048576): 	Total Chunks: 1, Chunks in use: 0. 1.60MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-12-05 17:03:16.602861: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-12-05 17:03:16.602896: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (4194304): 	Total Chunks: 1, Chunks in use: 0. 7.25MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-12-05 17:03:16.602935: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (8388608): 	Total Chunks: 1, Chunks in use: 1. 9.83MiB allocated for chunks. 9.83MiB in use in bin. 9.83MiB client-requested in use in bin.
# 2022-12-05 17:03:16.602976: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (16777216): 	Total Chunks: 1, Chunks in use: 1. 19.66MiB allocated for chunks. 19.66MiB in use in bin. 16.89MiB client-requested in use in bin.
# 2022-12-05 17:03:16.603009: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-12-05 17:03:16.603043: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-12-05 17:03:16.603082: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-12-05 17:03:16.603116: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-12-05 17:03:16.603154: I tensorflow/tsl/framework/bfc_allocator.cc:1057] Bin for 16.89MiB was 16.00MiB, Chunk State:
# 2022-12-05 17:03:16.603209: I tensorflow/tsl/framework/bfc_allocator.cc:1070] Next region of size 41353216
# 2022-12-05 17:03:16.603249: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 701fe0000 of size 256 next 1
# 2022-12-05 17:03:16.603279: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 701fe0100 of size 1280 next 2
# 2022-12-05 17:03:16.603308: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 701fe0600 of size 256 next 3
# 2022-12-05 17:03:16.603335: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 701fe0700 of size 256 next 4
# 2022-12-05 17:03:16.603422: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 701fe0800 of size 20615424 next 9
# 2022-12-05 17:03:16.603457: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 703389900 of size 10307328 next 10
# 2022-12-05 17:03:16.603551: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 703d5e000 of size 256 next 6
# 2022-12-05 17:03:16.603654: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 703d5e100 of size 256 next 7
# 2022-12-05 17:03:16.603795: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 703d5e200 of size 256 next 8
# 2022-12-05 17:03:16.603912: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 703d5e300 of size 256 next 11
# 2022-12-05 17:03:16.603943: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 703d5e400 of size 256 next 5
# 2022-12-05 17:03:16.603971: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 703d5e500 of size 256 next 12
# 2022-12-05 17:03:16.604034: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 703d5e600 of size 256 next 17
# 2022-12-05 17:03:16.604100: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 703d5e700 of size 256 next 15
# 2022-12-05 17:03:16.604149: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 703d5e800 of size 256 next 16
# 2022-12-05 17:03:16.604211: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 703d5e900 of size 256 next 21
# 2022-12-05 17:03:16.604242: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 703d5ea00 of size 256 next 20
# 2022-12-05 17:03:16.604271: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 703d5eb00 of size 256 next 22
# 2022-12-05 17:03:16.604311: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 703d5ec00 of size 256 next 23
# 2022-12-05 17:03:16.604340: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 703d5ed00 of size 256 next 24
# 2022-12-05 17:03:16.604368: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 703d5ee00 of size 256 next 25
# 2022-12-05 17:03:16.604396: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 703d5ef00 of size 256 next 26
# 2022-12-05 17:03:16.604423: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 703d5f000 of size 256 next 27
# 2022-12-05 17:03:16.604451: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 703d5f100 of size 256 next 28
# 2022-12-05 17:03:16.604480: I tensorflow/tsl/framework/bfc_allocator.cc:1090] Free  at 703d5f200 of size 201472 next 13
# 2022-12-05 17:03:16.604509: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 703d90500 of size 102400 next 14
# 2022-12-05 17:03:16.604537: I tensorflow/tsl/framework/bfc_allocator.cc:1090] Free  at 703da9500 of size 1676800 next 19
# 2022-12-05 17:03:16.604585: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 703f42b00 of size 838400 next 18
# 2022-12-05 17:03:16.604675: I tensorflow/tsl/framework/bfc_allocator.cc:1090] Free  at 70400f600 of size 7604736 next 18446744073709551615
# 2022-12-05 17:03:16.604741: I tensorflow/tsl/framework/bfc_allocator.cc:1095]      Summary of in-use Chunks by size:
# 2022-12-05 17:03:16.604812: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 21 Chunks of size 256 totalling 5.2KiB
# 2022-12-05 17:03:16.604865: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 1280 totalling 1.2KiB
# 2022-12-05 17:03:16.604918: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 102400 totalling 100.0KiB
# 2022-12-05 17:03:16.604974: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 838400 totalling 818.8KiB
# 2022-12-05 17:03:16.605027: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 10307328 totalling 9.83MiB
# 2022-12-05 17:03:16.605080: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 20615424 totalling 19.66MiB
# 2022-12-05 17:03:16.605132: I tensorflow/tsl/framework/bfc_allocator.cc:1102] Sum Total of in-use chunks: 30.39MiB
# 2022-12-05 17:03:16.605163: I tensorflow/tsl/framework/bfc_allocator.cc:1104] total_region_allocated_bytes_: 41353216 memory_limit_: 41353216 available bytes: 0 curr_region_allocation_bytes_: 82706432
# 2022-12-05 17:03:16.605243: I tensorflow/tsl/framework/bfc_allocator.cc:1110] Stats:
# Limit:                        41353216
# InUse:                        31870208
# MaxInUse:                     31870208
# NumAllocs:                          46
# MaxAllocSize:                 20615424
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-12-05 17:03:16.605306: W tensorflow/tsl/framework/bfc_allocator.cc:492] *******************************************xxxxxx***************************___***__________________
# 2022-12-05 17:03:16.685575: W tensorflow/core/framework/op_kernel.cc:1818] RESOURCE_EXHAUSTED: failed to allocate memory
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[40], line 29
#      27 trainX = encode_text(tokenizer, trainLines, length)
#      28 # define model
# ---> 29 model = define_model(length, vocab_size)
#      30 # fit model
#      31 model.fit([trainX,trainX,trainX], array(trainLabels), epochs=7, batch_size=16)
#
# Cell In[39], line 5, in define_model(length, vocab_size)
#       2 def define_model(length, vocab_size):
#       3 	# channel 1
#       4 	inputs1 = Input(shape=(length,))
# ----> 5 	embedding1 = Embedding(vocab_size, 100)(inputs1)
#       6 	conv1 = Conv1D(32, 4, activation='relu')(embedding1)
#       7 	drop1 = Dropout(0.5)(conv1)
#
# File ~/Documentos/Jupyter/jupyterEnv/lib/python3.8/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/Documentos/Jupyter/jupyterEnv/lib/python3.8/site-packages/keras/backend.py:2100, in RandomGenerator.random_uniform(self, shape, minval, maxval, dtype, nonce)
#    2098     if nonce:
#    2099         seed = tf.random.experimental.stateless_fold_in(seed, nonce)
# -> 2100     return tf.random.stateless_uniform(
#    2101         shape=shape,
#    2102         minval=minval,
#    2103         maxval=maxval,
#    2104         dtype=dtype,
#    2105         seed=seed,
#    2106     )
#    2107 return tf.random.uniform(
#    2108     shape=shape,
#    2109     minval=minval,
#    (...)
#    2112     seed=self.make_legacy_seed(),
#    2113 )
#
# ResourceExhaustedError: {{function_node __wrapped__Mul_device_/job:localhost/replica:0/task:0/device:GPU:0}} failed to allocate memory [Op:Mul]

# %% [markdown]
# <a id="section54"></a>
# # <font color="#004D7F" size=5>5.4. Evaluar el modelo</font>

# %% [markdown]
# Podemos evaluar el modelo de ajuste al predecir la reseña en todas las revisiones en el conjunto de datos de prueba no etiquetados

# %%
from pickle import load
from keras.models import load_model
from numpy import array
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# load datasets
trainLines, trainLabels = load_dataset('train.pkl')
testLines, testLabels = load_dataset('test.pkl')
# create tokenizer
tokenizer = create_tokenizer(trainLines)
# calculate max document length
length = max_length(trainLines)
print('Max document length: %d' % length)
# calculate vocabulary size
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary size: %d' % vocab_size)
# encode data
trainX = encode_text(tokenizer, trainLines, length)
testX = encode_text(tokenizer, testLines, length)
# load the model
model = load_model('model.h5')

# %% [markdown]
# Una vez cargado el modelo guardado podemos evaluarlo tanto en los conjuntos de datos de entrenamiento como de prueba.

# %%
# evaluate model on training dataset
_, acc = model.evaluate([trainX,trainX,trainX], array(trainLabels), verbose=0)
print('Train Accuracy: %.2f' % (acc*100))
# evaluate model on test dataset dataset
_, acc = model.evaluate([testX,testX,testX], array(testLabels), verbose=0)
print('Test Accuracy: %.2f' % (acc*100))

# %% [markdown]
# Ejecutar el ejemplo imprime la habilidad del modelo en los conjuntos de datos de entrenamiento y prueba. Podemos ver que, como era de esperar, la habilidad en el conjunto de datos de entrenamiento es excelente, aquí con una precisión del 100%.
#
# También podemos ver que la habilidad del modelo en el conjunto de datos de prueba no etiquetados también es muy impresionante, logrando un 88,5%, que está por encima de la habilidad del modelo informado en el documento de 2014.

# %% [markdown]
# ---
# <div style="text-align: right"> <font size=5> <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a></font></div>
#
# ---

# %% [markdown]
# <a id="section6"></a>
# # <font color="#004D7F" size=6>6. Extensiones</font>

# %% [markdown]
# <a id="section61"></a>
# # <font color="#004D7F" size=5>6.1. Extensiones sin n-gramas</font>

# %% [markdown]
# En esta sección se enumeran algunas ideas para ampliar el tutorial que tal vez desee explorar.
# - __Limpieza de datos__. Explore una mejor limpieza de datos, tal vez dejando algunos signos de puntuación intactos o normalizando las contracciones.
# - __Secuencias truncadas__. Rellenar todas las secuencias con la duración de la secuencia más larga puede ser extremo si la secuencia más larga es muy diferente a todas las demás revisiones. Estudie la distribución de la duración de las reseñas y trunque las reseñas a una duración media.
# - __Vocabulario truncado__. Eliminamos las palabras que aparecían con poca frecuencia, pero aún teníamos un gran vocabulario de más de 25,000 palabras. Explore aún más la reducción del tamaño del vocabulario y el efecto en la habilidad del modelo.
# - __Filtros y Tamaño del Kernel__. La cantidad de filtros y el tamaño del kernel son importantes para modelar la habilidad y no se ajustaron. Explore el tunning de estos dos parámetros de CNN.
# - __Épocas y tamaño de lote__. El modelo parece ajustarse rápidamente al conjunto de datos de entrenamiento. Explore configuraciones alternativas de la cantidad de épocas de entrenamiento y el tamaño del lote y use el conjunto de datos de prueba como un conjunto de validación para elegir un mejor punto de parada para entrenar el modelo.
# - __Red más profunda__. Explore si una red más profunda da como resultado una mejor habilidad, ya sea en términos de capas CNN, capas MLP y ambas.
# - __Pre-entrenamiento de Embedding__. Explore el entrenamiento previo de una palabra Word2Vec incrustada en el - modelo y el impacto en la habilidad del modelo con y sin ajustes adicionales durante el entrenamiento.
# - __Utilice el Embedding de _GloVe___. Explore la carga de la incrustación de GloVe previamente entrenada y el impacto en la habilidad del modelo con y sin más ajustes durante el entrenamiento.
# - __Revisiones de prueba más largas__. Explore si la habilidad de las predicciones del modelo depende de la duración de las reseñas de películas, como se sospecha en la sección final sobre la evaluación del modelo.
# - __Modelo Final Entrenado__. Entrene un modelo final con todos los datos disponibles y utilícelo para hacer predicciones sobre reseñas de películas ad hoc reales de Internet.

# %% [markdown]
# <a id="section62"></a>
# # <font color="#004D7F" size=5>6.2. Extensiones con n-gramas</font>

# %% [markdown]
# En esta sección se enumeran algunas ideas para ampliar el tutorial que tal vez desee explorar.
# - __Diferentes n-gramas__. Explore el modelo cambiando el tamaño del kernel (número de n-gramas) que utilizan los canales en el modelo para ver cómo afecta la habilidad del modelo.
# - __Más o menos canales__. Explore el uso de más o menos canales en el modelo y vea cómo afecta la habilidad del modelo.
# - __Incrustación compartida__. Explore configuraciones donde cada canal comparte la misma palabra incrustada e informe sobre el impacto en la habilidad del modelo.
# - __Red más profunda__. Las redes neuronales convolucionales funcionan mejor en visión artificial cuando son más profundas. Explore el uso de modelos más profundos aquí y vea cómo afecta la habilidad del modelo.
# - __Secuencias truncadas__. Rellenar todas las secuencias con la duración de la secuencia más larga puede ser extremo si la secuencia más larga es muy diferente a todas las demás revisiones. Estudie la distribución de la duración de las reseñas y trunque las reseñas a una duración media.
# - __Vocabulario truncado__. Eliminamos las palabras que aparecían con poca frecuencia, pero aún teníamos un gran vocabulario de más de 25,000 palabras. Explore aún más la reducción del tamaño del vocabulario y el efecto en la habilidad del modelo.
# - __Épocas y tamaño de lote__. El modelo parece ajustarse rápidamente al conjunto de datos de entrenamiento. Explore configuraciones alternativas de la cantidad de épocas de entrenamiento y el tamaño del lote y use el conjunto de datos de prueba como un conjunto de validación para elegir un mejor punto de parada para entrenar el modelo.
# - __Pre-entrenamiento e incrustación__. Explore el entrenamiento previo de una palabra Word2Vec incrustada en el modelo y el impacto en la habilidad del modelo con y sin ajustes adicionales durante el entrenamiento.
# - __Utilice la incrustación de GloVe__. Explore la carga de la incrustación de GloVe previamente entrenada y el impacto en la habilidad del modelo con y sin más ajustes durante el entrenamiento.
# - __Entrenamiento del Modelo Final__. Entrene un modelo final con todos los datos disponibles y utilícelo para hacer predicciones sobre reseñas de películas ad hoc reales de Internet.

# %% [markdown]
# <div style="text-align: right"> <font size=5> <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a></font></div>
#
# ---
#
# <div style="text-align: right"> <font size=6><i class="fa fa-coffee" aria-hidden="true" style="color:#004D7F"></i> </font></div>
